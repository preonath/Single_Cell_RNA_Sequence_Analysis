# %% [markdown]
# ### **HIVE scRNAseq Analysis v1.3.2** ###
# #### **Honeycomb Bioinformatics Team** ####
# 2023-10-06

# %% [markdown]
# #### **1 HIVE scRNAseq Analysis Vignette** ####
# The document contains code and instructions to analyze single cell sequencing data generated by HIVE scRNAseq Solution. This analysis is intended as guidance to perform quality control, basic clustering and cell annotation for one experiments worth of samples. This example experiment has four samples where 7.5k or 30k cells were loaded into two HIVEs each (4 total HIVEs).
#
# Please contact support@honeycomb.bio for all questions.
#
# The below packages need to be installed prior to running this code. There may be additional dependencies required by these packages you may have to install depending on your R environment.

# %%
.libPaths("/home/chrf/anaconda3/envs/ir-4.3/lib/R/library")

# %%
Sys.which("R")

# %%
library(tidyverse)

# %%
# install.packages("htmltools", dependencies=TRUE)
# install.packages("tidyverse", dependencies=TRUE)
# install.packages("patchwork")
# install.packages("plyr")
# install.packages('Seurat')
# library(Seurat)
# install.packages('Seurat', dependencies=TRUE)
# if (!require("BiocManager", quietly = TRUE)){
#   install.packages("BiocManager")
# }
# BiocManager::install("UCell")
# install.packages("ggpubr")
# BiocManager::install("SingleCellExperiment")
# BiocManager::install("scuttle")
# BiocManager::install("celldex")
# install.packages("DT")
# if (!requireNamespace("remotes", quietly = TRUE)) {
#   install.packages("remotes")
# }
# install.packages("HGNChelper")
# Out:
# Installing package into ‘/home/chrf/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)

# %%
suppressPackageStartupMessages({
library(tidyverse)
library(patchwork)
library(plyr)
library(Seurat)
library(UCell)
library(ggpubr)
library(SingleCellExperiment)
library(scuttle)
library(celldex)
library(DT)
library(scales)
library(UCell)
library(HGNChelper)
library(openxlsx)
})

# %% [markdown]
# #### **1.1 Finding Count Matrices and Setting Up Metadata** ####
# Be sure that you specify the correct path to your count matrices, readQC, and sample QC files. If these files are not located in the current working directory, please provide the full path in quotation marks in the code below.
#
# We recommend making a unique folder for your analysis. In this folder, we recommend making subfolders for each sample that contain all of the files necessary for this analysis. Here is an example of our recommended file tree, and the file tree that this tutorial is written for:
#
#
#
#
# Please enter the sample names into the sampleslist argument below. The sample names in this list must match the sample names in the BeeNet output files. For example, if the transcription count matrix file is named MySample1_20230426182713_TCM.tsv.gz, then your sample name is MySample1. Furthermore, if you would like to compare samples based on a particular metadata, enter that metadata into the “groupslist”. Order matters! In this example, samples 1 and 2 were loaded with 7.5k cells, and samples 3 and 4 were loaded with 30k cells. Be sure to preserve the order when entering this data.

# %%
# Set the paths to the directories containing your files
base_path_1 <- "/media/asus/275dd380-2319-4638-bcdd-5f65b2b1d4b5/CHRF_Project_Data/Single_Cell/Honeycomb_Biotechnologies/Data_Analysis/3_Additional_Analysis_Resources/1_Example_Data_for_BeeNetPLUS/1_Practice_running_BeeNetPLUS_using_this_dataset/BeeNetOutputs/Beenet_SC_NP_H_7061"
base_path_2 <- "/media/asus/275dd380-2319-4638-bcdd-5f65b2b1d4b5/CHRF_Project_Data/Single_Cell/Honeycomb_Biotechnologies/Data_Analysis/3_Additional_Analysis_Resources/1_Example_Data_for_BeeNetPLUS/1_Practice_running_BeeNetPLUS_using_this_dataset/BeeNetOutputs/Beenet_SC_NP_H_7063"

# Combine both base paths into a list
base_paths <- list(base_path_1, base_path_2)

# Initialize empty lists to store file paths
CMfiles <- list()
readsFiles <- list()
samplesFiles <- list()

# Iterate over each base path
for (base_path in base_paths) {
  # Transcript count matrix files
  CMfiles_tmp <- list.files(path = base_path, pattern = "TCM.tsv.gz", full.names = TRUE)
  CMfiles <- c(CMfiles, CMfiles_tmp)

  # ReadsQC files
  readsFiles_tmp <- list.files(path = base_path, pattern = "ReadsQC.tsv", full.names = TRUE)
  readsFiles <- c(readsFiles, readsFiles_tmp)

  # SampleQC files
  samplesFiles_tmp <- list.files(path = base_path, pattern = "SampleQC.tsv", full.names = TRUE)
  samplesFiles <- c(samplesFiles, samplesFiles_tmp)
}

# Print the lists of files
print("Transcript count matrix files:")
print(CMfiles)

print("ReadsQC files:")
print(readsFiles)

print("SampleQC files:")
print(samplesFiles)

# Replace sample names below with the name of your sample. Make sure that the order of the samples and the order of the groups are correct!
sampleslist <- c("SC_NP_H_7061", "SC_NP_H_7063") # Corrected to include both samples
groupslist <- c("15k", "15k")



# Print the lists of samples and groups
print("Sample list:")
print(sampleslist)

print("Groups list:")
print(groupslist)

# %% [markdown]
# You should now see a list of your count matrices files and your readsQC files in your R environment
#
# ##### **1.2 Read Count Matrices and Create a Seurat Object for each sample** #####
# Here we define a function called generate_seurat_object() to create Seurat objects from the BeeNet Outputs. This function reads in count matrices and adds metadata to your Seurat object.

# %%
# Function to generate Seurat object
generate_seurat_object <- function(sample, group_name = "", CMfiles, readsFiles){
  
  # Find matching file paths for CM and Reads files
  CMfile_matches <- grep(sample, CMfiles, value = TRUE)
  readsFile_matches <- grep(sample, readsFiles, value = TRUE)

  # Check if exactly one matching file is found for each type
  if(length(CMfile_matches) != 1) {
    stop("Expected one matching CM file for sample '", sample, "', but found ", length(CMfile_matches))
  }
  if(length(readsFile_matches) != 1) {
    stop("Expected one matching Reads file for sample '", sample, "', but found ", length(readsFile_matches))
  }

  # Use the matched file paths
  CMfile_path <- CMfile_matches[1]
  readsFile_path <- readsFile_matches[1]

  # Load count matrix file
  dataTran <- read.table(CMfile_path, header = TRUE, row.names = 1, check.names = FALSE, sep = "\t", quote = "", stringsAsFactors = FALSE) 
  
  # Load read info for each barcode
  dataReads <- read.table(readsFile_path, header = TRUE, row.names = 1)
  
  # Ensure order of read info matches order of TCM matrix
  table(rownames(dataReads) == colnames(dataTran))
  reads = dataReads[rownames(dataReads) %in% colnames(dataTran),]

  # Create a Seurat Object
  obj <- CreateSeuratObject(counts = dataTran, project = sample)
  
  # Calculate metadata info
  logtotreads <- log10(as.matrix(reads)[,1])
  readAll <- dataReads[,1]
  readMap <- reads[,2]
  readMapPct <- readMap / readAll
  readUnmap <- readAll - readMap
  readUnmapPct <- readUnmap / readAll
  readExon <- reads[,3]
  readExonPct <- readExon / readAll
  readExonMapPct <- readExon / readMap
  names(readExon) <- colnames(obj)
  obj <- AddMetaData(obj, readExon, "ExonReads")
  names(readExonMapPct) <- colnames(obj)
  names(readExonPct) <- colnames(obj)
  names(readMap) <- colnames(obj)
  names(readAll) <- colnames(obj)
  
  # Add metadata to object
  obj <- AddMetaData(obj, logtotreads, "Log.TotReads") 
  obj <- AddMetaData(obj, readExonMapPct, "ExonvMapped")
  obj <- AddMetaData(obj, readExonPct, "ExonvTotal")
  obj <- AddMetaData(obj, readMap, "reads.mapped")
  obj <- AddMetaData(obj, readAll, "reads.Total")

  # Calculate complexity and add to metadata
  comp = obj@meta.data$ExonReads / obj@meta.data$nCount_RNA
  names(comp) <- rownames(obj@meta.data)
  obj <- AddMetaData(obj, comp, "Complexity")
  
  # Add group and groupSamp
  obj$group <- group_name
  obj$groupSamp <- paste(group_name, sample, sep = "_")

  return(obj)
}

# %% [markdown]
# Next, run the function on each sample to generate a seurat object for each sample. From there, merge the individual objects into a final objects and remove the individual objects.

# %%
# Generate Seurat objects for each sample
seurat_list <- purrr::map2(sampleslist, groupslist, 
                    ~ generate_seurat_object(sample = .x,
                                             group_name = .y,
                                             CMfiles = CMfiles,
                                             readsFiles = readsFiles))

# Merge individual objects into a final Seurat object if more than one sample
if(length(seurat_list) > 1) {
  obj <- merge(x = seurat_list[[1]], 
               y = seurat_list[2:length(seurat_list)], 
               add.cell.ids = sampleslist)
} else {
  obj <- seurat_list[[1]]
}

# Remove seurat_list to clear up memory
remove(seurat_list)
# Out:
# Warning message:
# “Feature names cannot have underscores ('_'), replacing with dashes ('-')”
# Warning message:
# “Data is of class data.frame. Coercing to dgCMatrix.”
# Warning message:
# “Feature names cannot have underscores ('_'), replacing with dashes ('-')”
# Warning message:
# “Data is of class data.frame. Coercing to dgCMatrix.”

# %% [markdown]
# ##### **1.3 Filtering Cells** #####
# We removed cells with:
#
# Fewer than 300 genes
# Fewer than 600 unique transcript molecules.
# This will be highly sample dependent. If you find that you lose too many cells filtering with these thresholds, we recommend filtering with a lower threshold (50 genes/100 transcripts) and then removing low quality clusters.

# %%
## determine how many cells are recovered before filtering
ncol(obj)
# Out:
# [1] 12000

# %%
## filter features that have less than 300 genes and 600 unique transcript molecules
nGeneI=300
nTranI=600
obj <- subset(obj, subset = nFeature_RNA > nGeneI & nCount_RNA > nTranI)
obj
# Out:
# An object of class Seurat
# 16414 features across 49 samples within 1 assay
# Active assay: RNA (16414 features, 0 variable features)
#  2 layers present: counts.SC_NP_H_7061, counts.SC_NP_H_7063

# %%
## determine how many cells are recovered after filtering
ncol(obj)
# Out:
# [1] 49

# %% [markdown]
# ##### **1.4 Quality Control** #####
# ###### **1.4.1 QC** ######

# %%
# Add mitochondrial content
# Adjust the pattern based on your mitochondrial gene names
obj[["percent.mito"]] <- PercentageFeatureSet(obj, pattern = "^MT-")

# Identify mitochondrial genes - adjust the patterns based on your reference genome
mito.genes <- grep("^MT\\.", rownames(obj@assays$RNA), value = TRUE)
mito.genes <- c(mito.genes, grep("^MT-", rownames(obj@assays$RNA), value = TRUE))

# Plot the QC metrics in a violin plot with scatter data
VlnPlot(obj, features = c("nFeature_RNA", "nCount_RNA", "percent.mito"), 
        pt.size = 1, # Adjust the point size as needed
        ncol = 3, 
        combine = TRUE) +  # Combine violin and scatter plots
  theme(axis.title.x = element_blank(),
        axis.text.x = element_blank(),
        axis.ticks.x = element_blank())
# Out:
# Warning message:
# “Default search for "data" layer in "RNA" assay yielded no results; utilizing "counts" layer instead.”
# plot without title

# %% [markdown]
# ###### **1.4.1.2 QC - Scatter Plots** ######

# %%
## plot scatter QC 
plot1 <- FeatureScatter(obj, feature1 = "nCount_RNA", feature2 = "percent.mito") + 
  theme(axis.text.x = element_text(angle = 90))
plot2 <- FeatureScatter(obj, feature1 = "nCount_RNA", feature2 = "nFeature_RNA") + 
  theme(axis.text.x = element_text(angle = 90))

plot1 + plot2
# Out:
# plot without title

# %% [markdown]
# ###### **1.4.1.3 QC - QC Metrics by Sample** ######
# Use the qc_metrics_sample function below to obtain a table containing quality metrics for each sample. Rerun this function every time you remove or subset cells, or change the gene/threshold parameters.

# %%
# Assuming sampleslist and samplesFile are defined earlier in your code

# Load Total read info
totReads.df <- data.frame()

for (sample in sampleslist) {
  file_matches <- grep(sample, samplesFile, value = TRUE)
  
  # Check if there are valid file matches
  if (length(file_matches) == 0) {
    warning("No files found for sample: ", sample)
    next
  }

  sampleqcinfo <- read.table(file_matches[1], sep = "\t", header = TRUE)
  specs <- sampleqcinfo[, 1]
  totReads.df <- cbind(totReads.df, sampleqcinfo[, 2])
  row.names(totReads.df) <- specs
}

# Check if totReads.df is not empty before setting column names
if (ncol(totReads.df) > 0) {
  colnames(totReads.df) <- sampleslist
} else {
  warning("No valid data found. Check your file paths and contents.")
}

# Define the quality control metrics function
qc_metrics_sample <- function(obj) {
  I = obj@meta.data$orig.ident
  Reads = obj@meta.data$ExonReads
  ReadsM = obj@meta.data$reads.mapped
  ReadsT = obj@meta.data$reads.Total
  trans = obj@meta.data$nCount_RNA
  Genes = obj@meta.data$nFeature_RNA
  Mito = obj@meta.data$percent.mito
  Complexity = obj@meta.data$Complexity
  
  nSamples = length(sampleslist)
  readEC = vector(mode = "double", length = nSamples)
  readsTot = totReads.df
  readsTotalSamples = colnames(readsTot)
  names(readEC) = sampleslist
  readTC = readEC
  readMC = readEC
  transC = readEC
  geneC = readEC
  mitoC = readEC
  nCells = readEC
  compl = readEC
  readsCellTotal = readEC
  readsSampleTotal = readEC
  FracCellReads = readEC
  readsSampleMapped = readEC
  readsSampleFiltered = readEC
  readsSampleExon = readEC
  percExon = readEC
  percFilt = readEC

  for (x in 1:nSamples) {
    readTC[x] = median(ReadsT[is.na(match(I, sampleslist[x])) == 0])
    readEC[x] = median(Reads[is.na(match(I, sampleslist[x])) == 0])
    readMC[x] = median(ReadsM[is.na(match(I, sampleslist[x])) == 0])
    transC[x] = median(trans[is.na(match(I, sampleslist[x])) == 0])
    geneC[x] = median(Genes[is.na(match(I, sampleslist[x])) == 0])
    mitoC[x] = median(Mito[is.na(match(I, sampleslist[x])) == 0])
    compl[x] = median(Complexity[is.na(match(I, sampleslist[x])) == 0])
    nCells[x] = sum(is.na(match(I, sampleslist[x])) == 0)
    readsCellTotal[x] = sum(ReadsT[is.na(match(I, sampleslist[x])) == 0])
    readsSampleTotal[x] = readsTot[1, is.na(match(readsTotalSamples, sampleslist[x])) == 0]
    FracCellReads[x] = readsCellTotal[x] / readsSampleTotal[x]
    readsSampleMapped[x] = readsTot[3, is.na(match(readsTotalSamples, sampleslist[x])) == 0]
    readsSampleFiltered[x] = readsTot[2, is.na(match(readsTotalSamples, sampleslist[x])) == 0]
    readsSampleExon[x] = readsTot[4, is.na(match(readsTotalSamples, sampleslist[x])) == 0]
    percExon[x] = readEC[x] / readTC[x] * 100
    percFilt[x] = readsSampleFiltered[x] / readsSampleTotal[x]
  }

  clustInfo = data.frame(SampleID = sampleslist, Group = groupslist, TotalReads = readTC,
                         MappedReads = readMC, ExonReads = readEC, nTrans = transC,
                         nGenes = geneC, percMito = mitoC, nCells = nCells,
                         Complexity = compl, SampleTotalReads = readsSampleTotal,
                         SampleFilteredReads = readsSampleFiltered,
                         SampleMappedReads = readsSampleMapped, SampleExonReads = readsSampleExon,
                         HQCellsTotalReads = readsCellTotal, FracReadsHQCells = FracCellReads,
                         PctExon = percExon, FracPassFilter = percFilt)
  
  write.table(clustInfo, "SamplesMetrics.txt", sep = "\t", col.names = NA)
  
  return(clustInfo)
}

# Call the function with your Seurat object
sample_metrics <- qc_metrics_sample(obj)

# Assuming you have 'datatable' from DT package for displaying the data frame
datatable(sample_metrics)
# Out:
# Warning message in eval(expr, envir, enclos):
# “No files found for sample: SC_NP_H_7061”
# Warning message in eval(expr, envir, enclos):
# “No files found for sample: SC_NP_H_7063”
# Warning message in eval(expr, envir, enclos):
# “No valid data found. Check your file paths and contents.”
# Error in readsSampleTotal[x] <- readsTot[1, is.na(match(readsTotalSamples, : replacement has length zero
# Traceback:
#
# 1. qc_metrics_sample(obj)

# %% [markdown]
# ###### **1.4.1.4 QC - Sequencing Plots** ######

# %%
colors=rep(c("#ED7D30","#0058D4", "#7D3C98", "#F4D03F", "#16A085", "#721236", 
             "#A0CBE8", "#FFBE7D", "#59A14F", "#FF9D9A", "#79706E", "#8CD17D", 
             "#499894", "#BAB0AC", "#D37295", "#FABFD2", "#B07AA1"),5)

p <- ggplot(sample_metrics, aes(Group, SampleTotalReads)) + 
  ggtitle("Total Sample Reads by Group") 

# calculate axis limits for plots
d=floor(log(max(sample_metrics$SampleTotalReads),10))
yL=ceiling(max(sample_metrics$SampleTotalReads)/10^d)*10^d

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, FracPassFilter)) + 
  ggtitle("Frac Reads Pass Filter by Group")

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,1))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, PctExon)) + 
  ggtitle("% Exon Reads by Group")

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,100))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, ExonReads)) + 
  ggtitle("Median Exon Reads per Cell by Group")

# calculate axis limits for plots
d=floor(log(max(sample_metrics$ExonReads),10))
yL=ceiling(max(sample_metrics$ExonReads)/10^d)*10^d

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, Complexity)) + 
  ggtitle("Complexity (Exon Reads/Transcript) by Group")

# calculate axis limits for plots
yL=5*ceiling(max(sample_metrics$Complexity)/5)

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, TotalReads)) + 
  ggtitle("Median Total Reads per Cell by Group")

# calculate axis limits for plots
d=floor(log(max(sample_metrics$TotalReads),10))
yL=ceiling(max(sample_metrics$TotalReads)/10^d)*10^d

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, SeqSat)) + 
  ggtitle("Sequencing Saturation by Group")

yL=100

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  ylim(c(0,1))
# Out:
# plot without title

# %% [markdown]
# ##### **1.4.2 Cell Recovery** #####
# Using your sample metrics table, make plots to display cell/gene/transcript recovery. In this example, only 1/8 of the HIVE was sequenced, so cell recovery is 1/8 of what would be expected for these samples.
#
# Here are a few things to look for in your data.
#
# Median Genes by Group: > 800. This number is sample dependent. It is usually higher for cell lines and lower for samples that contain granulocytes.
#
# Median Transcripts by Group: > 1200. This number is sample dependent. It is usually higher for cell lines and lower for samples that contain granulocytes.
#
# Percent Mito by Group: < 20%.

# %%
p <- ggplot(sample_metrics, aes(Group, nCells)) + 
  ggtitle("Cells Recovered by Group (Remember- Multiply by 8 to get stats for full HIVE!)")

# calculate axis limits for plots
yL=500*ceiling(max(sample_metrics$nCells/500))

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, nGenes)) + 
  ggtitle("Median Genes by Group")

# calculate axis limits for plots
yL=500*ceiling(max(sample_metrics$nGenes)/500) 

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, nTrans)) + 
  ggtitle("Median Transcripts by Group")

# calculate axis limits for plots
yL=500*ceiling(max(sample_metrics$nTrans)/500) 

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %%
p <- ggplot(sample_metrics, aes(Group, percMito)) + 
  ggtitle("% Mito by Group")

yL=50

p + geom_boxplot(outlier.shape = NA, aes(fill = Group) ) + 
  scale_fill_manual(values=colors) + 
  geom_jitter(width = 0.2) + 
  ylim(c(0,yL))
# Out:
# plot without title

# %% [markdown]
# #### **1.5 Dimensionality Reduction** ####

# %%
## Dimensionality Reduction
obj <- NormalizeData(obj)
obj <- ScaleData(obj)
obj <- FindVariableFeatures(obj, selection.method = "vst", nfeatures = 2000)
obj <- RunPCA(obj, verbose = FALSE)
obj <- RunUMAP(obj, dims=1:30,verbose = FALSE)
obj <- FindNeighbors(obj,verbose = FALSE)
obj <- FindClusters(obj, verbose = FALSE)
obj <- BuildClusterTree(obj,reorder=TRUE,reorder.numeric=TRUE)
obj$seurat_clusters <- obj$tree.ident

#Run SCTransform if percent.mito is present in metadata
if (is.null(mito.genes)==FALSE){
    obj <- SCTransform(obj, vars.to.regress = "percent.mito", verbose = FALSE)
} else {
    obj <- SCTransform(obj, verbose = FALSE)
}
obj <- RunPCA(obj, verbose = FALSE)
obj <- RunUMAP(obj, dims=1:18,verbose = FALSE)
obj <- FindNeighbors(obj,verbose = FALSE)
obj <- FindClusters(obj, verbose = FALSE)
obj <- BuildClusterTree(obj,reorder=TRUE,reorder.numeric=TRUE)
obj$seurat_clusters <- obj$tree.ident
# Out:
# Normalizing layer: counts.SC_NP_H_7061
#
# Normalizing layer: counts.SC_NP_H_7063
#
# Centering and scaling data matrix
#
# Finding variable features for layer counts.SC_NP_H_7061
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -1.6816”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.31989”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 0.031008”
# Finding variable features for layer counts.SC_NP_H_7063
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “at  -0.49026”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “radius  0.00017271”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “all data on boundary of neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at -0.49026”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 0.013142”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  1”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “zero-width neighborhood. make span bigger”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 0.090619”
# Error in irlba(A = t(x = object), nv = npcs, ...): max(nu, nv) must be strictly less than min(nrow(A), ncol(A))
# Traceback:
#
# 1. RunPCA(obj, verbose = FALSE)
# 2. RunPCA.Seurat(obj, verbose = FALSE)
# 3. RunPCA(object = object[[assay]], assay = assay, features = features,
#  .     npcs = npcs, rev.pca = rev.pca, weight.by.var = weight.by.var,
#  .     verbose = verbose, ndims.print = ndims.print, nfeatures.print = nfeatures.print,
#  .     reduction.key = reduction.key, seed.use = seed.use, ...)
# 4. RunPCA.StdAssay(object = object[[assay]], assay = assay, features = features,
#  .     npcs = npcs, rev.pca = rev.pca, weight.by.var = weight.by.var,
#  .     verbose = verbose, ndims.print = ndims.print, nfeatures.print = nfeatures.print,
#  .     reduction.key = reduction.key, seed.use = seed.use, ...)
# 5. RunPCA(object = data.use, assay = assay, npcs = npcs, rev.pca = rev.pca,
#  .     weight.by.var = weight.by.var, verbose = verbose, ndims.print = ndims.print,
#  .     nfeatures.print = nfeatures.print, reduction.key = reduction.key,
#  .     seed.use = seed.use, ...)
# 6. RunPCA.default(object = data.use, assay = assay, npcs = npcs,
#  .     rev.pca = rev.pca, weight.by.var = weight.by.var, verbose = verbose,
#  .     ndims.print = ndims.print, nfeatures.print = nfeatures.print,
#  .     reduction.key = reduction.key, seed.use = seed.use, ...)
# 7. irlba(A = t(x = object), nv = npcs, ...)
# 8. stop("max(nu, nv) must be strictly less than min(nrow(A), ncol(A))")

# %% [markdown]
# ##### **1.5.1 UMAP Plots** #####
# ###### **1.5.1.1 Clusters** ######

# %%
DimPlot(obj, reduction="umap")
# Out:
# Error in `object[[reduction]]`:
# ! ‘umap’ not found in this Seurat object
#
# Traceback:
#
# 1. DimPlot(obj, reduction = "umap")
# 2. cells %||% Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 3. Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 4. Cells.Seurat(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 5. assay[1L] %||% DefaultAssay(object = x)
# 6. DefaultAssay(object = object[[reduction]])
# 7. object[[reduction]]
# 8. `[[.Seurat`(object, reduction)
# 9. tryCatch(expr = arg_match(arg = i, values = meta.cols, multiple = TRUE),
#  .     error = function(e) {
#  .         abort(message = paste(paste(sQuote(x = setdiff(x = i,
#  .             y = meta.cols)), collapse = ", "), "not found in this Seurat object\n",
#  .             e$body), call = rlang::caller_env(n = 4L))
#  .     })
# 10. tryCatchList(expr, classes, parentenv, handlers)
# 11. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 12. value[[3L]](cond)
# 13. abort(message = paste(paste(sQuote(x = setdiff(x = i, y = meta.cols)),
#   .     collapse = ", "), "not found in this Seurat object\n", e$body),
#   .     call = rlang::caller_env(n = 4L))
# 14. signal_abort(cnd, .file)

# %%
#The UMAP can be colored or split by sample or group

DimPlot(obj, reduction="umap", group.by = "orig.ident")
# Out:
# Error in `object[[reduction]]`:
# ! ‘umap’ not found in this Seurat object
#
# Traceback:
#
# 1. DimPlot(obj, reduction = "umap", group.by = "orig.ident")
# 2. cells %||% Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 3. Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 4. Cells.Seurat(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 5. assay[1L] %||% DefaultAssay(object = x)
# 6. DefaultAssay(object = object[[reduction]])
# 7. object[[reduction]]
# 8. `[[.Seurat`(object, reduction)
# 9. tryCatch(expr = arg_match(arg = i, values = meta.cols, multiple = TRUE),
#  .     error = function(e) {
#  .         abort(message = paste(paste(sQuote(x = setdiff(x = i,
#  .             y = meta.cols)), collapse = ", "), "not found in this Seurat object\n",
#  .             e$body), call = rlang::caller_env(n = 4L))
#  .     })
# 10. tryCatchList(expr, classes, parentenv, handlers)
# 11. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 12. value[[3L]](cond)
# 13. abort(message = paste(paste(sQuote(x = setdiff(x = i, y = meta.cols)),
#   .     collapse = ", "), "not found in this Seurat object\n", e$body),
#   .     call = rlang::caller_env(n = 4L))
# 14. signal_abort(cnd, .file)

# %%
DimPlot(obj, reduction="umap", group.by = "group")
# Out:
# Error in `object[[reduction]]`:
# ! ‘umap’ not found in this Seurat object
#
# Traceback:
#
# 1. DimPlot(obj, reduction = "umap", group.by = "group")
# 2. cells %||% Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 3. Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 4. Cells.Seurat(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 5. assay[1L] %||% DefaultAssay(object = x)
# 6. DefaultAssay(object = object[[reduction]])
# 7. object[[reduction]]
# 8. `[[.Seurat`(object, reduction)
# 9. tryCatch(expr = arg_match(arg = i, values = meta.cols, multiple = TRUE),
#  .     error = function(e) {
#  .         abort(message = paste(paste(sQuote(x = setdiff(x = i,
#  .             y = meta.cols)), collapse = ", "), "not found in this Seurat object\n",
#  .             e$body), call = rlang::caller_env(n = 4L))
#  .     })
# 10. tryCatchList(expr, classes, parentenv, handlers)
# 11. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 12. value[[3L]](cond)
# 13. abort(message = paste(paste(sQuote(x = setdiff(x = i, y = meta.cols)),
#   .     collapse = ", "), "not found in this Seurat object\n", e$body),
#   .     call = rlang::caller_env(n = 4L))
# 14. signal_abort(cnd, .file)

# %%
DimPlot(obj, reduction="umap", split.by = "group")
# Out:
# Error in `object[[reduction]]`:
# ! ‘umap’ not found in this Seurat object
#
# Traceback:
#
# 1. DimPlot(obj, reduction = "umap", split.by = "group")
# 2. cells %||% Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 3. Cells(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 4. Cells.Seurat(x = object, assay = DefaultAssay(object = object[[reduction]]))
# 5. assay[1L] %||% DefaultAssay(object = x)
# 6. DefaultAssay(object = object[[reduction]])
# 7. object[[reduction]]
# 8. `[[.Seurat`(object, reduction)
# 9. tryCatch(expr = arg_match(arg = i, values = meta.cols, multiple = TRUE),
#  .     error = function(e) {
#  .         abort(message = paste(paste(sQuote(x = setdiff(x = i,
#  .             y = meta.cols)), collapse = ", "), "not found in this Seurat object\n",
#  .             e$body), call = rlang::caller_env(n = 4L))
#  .     })
# 10. tryCatchList(expr, classes, parentenv, handlers)
# 11. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 12. value[[3L]](cond)
# 13. abort(message = paste(paste(sQuote(x = setdiff(x = i, y = meta.cols)),
#   .     collapse = ", "), "not found in this Seurat object\n", e$body),
#   .     call = rlang::caller_env(n = 4L))
# 14. signal_abort(cnd, .file)

# %% [markdown]
# ###### **1.5.1.2 Cell Features** ######
# Feature plots can be used to plot most variables in your dataset. You can use this plot for genes and transcripts, but can also use these plots to plot expression of your favorite gene!

# %%
features <- c("nCount_RNA", "nFeature_RNA","percent.mito","CD8A")
FeaturePlot(obj, features = features)
# Out:
# Error in `DefaultDimReduc()`:
# ! Unable to find a DimReduc matching one of 'umap', 'tsne', or 'pca'; please specify a dimensional reduction to use
# Traceback:
#
# 1. FeaturePlot(obj, features = features)
# 2. reduction %||% DefaultDimReduc(object = object)
# 3. DefaultDimReduc(object = object)
# 4. abort(message = paste0("Unable to find a DimReduc matching one of ",
#  .     .Oxford(drs.use), "; please specify a dimensional reduction to use"))
# 5. signal_abort(cnd, .file)

# %% [markdown]
# ##### **1.5.2 Violin Plot** #####
# Here we look at the number of transcripts detected in each cell, broken out by cluster. Once clustering is performed, the “identity” of each cell barcode is its cluster number, which is why this graph is separated by cluster. You can change identities of the cell at any time (See the next section on how to change the identity to “cell type”)

# %%
VlnPlot(obj, features = 'nCount_RNA', pt.size = 0) +
  theme(axis.title.x = element_blank())
# Out:
# plot without title

# %% [markdown]
# ##### **1.5.3 scType - Cell Type Identification** #####
# For a preliminary cell type ID, we use scType (https://github.com/IanevskiAleksandr/sc-type). This annotator works best for human and mouse samples but may also apply to other reference genomes.

# %%
# Access the RNA assay of the Seurat object
rna_assay <- obj$RNA

# Get the gene names (rownames of the RNA assay)
gene_names <- rownames(rna_assay)

# Print the first few gene names
gene_names
# Out:
#     [1] "5S-rRNA"                   "7SK"
#     [3] "A2ML1"                     "A2MP1"
#     [5] "A4GALT"                    "AAAS"
#     [7] "AACS"                      "AACSP1"
#     [9] "AADACP1"                   "AADAT"
#    [11] "AAGAB"                     "AAK1"
#    [13] "AAMDC"                     "AAMP"
#    [15] "AAR2"                      "AARS1"
#    [17] "AARS2"                     "AARSD1"
#    [19] "AASDH"                     "AASDHPPT"
#    [21] "AASS"                      "AATF"
#    [23] "ABAT"                      "ABCA1"
#    [25] "ABCA11P"                   "ABCA12"
#    [27] "ABCA13"                    "ABCA2"
#    [29] "ABCA4"                     "ABCA5"
#    [31] "ABCA6"                     "ABCA7"
#    [33] "ABCA9"                     "ABCB10"
#    [35] "ABCB11"                    "ABCB4"
#    [37] "ABCB6"                     "ABCB7"
#    [39] "ABCB8"                     "ABCB9"
#    [41] "ABCC1"                     "ABCC3"
#    [43] "ABCC5"                     "ABCC6"
#    [45] "ABCC6P1"                   "ABCC8"
#    [47] "ABCC9"                     "ABCD1"
#    [49] "ABCD3"                     "ABCD4"
#    [51] "ABCE1"                     "ABCF1"
#    [53] "ABCF2"                     "ABCG1"
#    [55] "ABCG5"                     "ABHD11"
#    [57] "ABHD11-AS1"                "ABHD12"
#    [59] "ABHD12B"                   "ABHD13"
#    [61] "ABHD14A-ACY1"              "ABHD14B"
#    [63] "ABHD16A"                   "ABHD17A"
#    [65] "ABHD17AP6"                 "ABHD17B"
#    [67] "ABHD17C"                   "ABHD2"
#    [69] "ABHD4"                     "ABHD5"
#    [71] "ABI1"                      "ABI2"
#    [73] "ABITRAM"                   "ABL1"
#    [75] "ABL2"                      "ABLIM1"
#    [77] "ABO"                       "ABR"
#    [79] "ABRACL"                    "ABRAXAS1"
#    [81] "ABRAXAS2"                  "ABTB1"
#    [83] "ACAA1"                     "ACAA2"
#    [85] "ACACA"                     "ACACB"
#    [87] "ACAD10"                    "ACAD11"
#    [89] "ACAD8"                     "ACAD9"
#    [91] "ACADL"                     "ACADM"
#    [93] "ACADS"                     "ACADVL"
#    [95] "ACAP1"                     "ACAP2"
#    [97] "ACAP3"                     "ACAT1"
#    [99] "ACAT2"                     "ACBD3"
#   [101] "ACBD3-AS1"                 "ACBD4"
#   [103] "ACBD5"                     "ACBD6"
#   [105] "ACBD7"                     "ACCS"
#   [107] "ACCSL"                     "ACER3"
#   [109] "ACIN1"                     "ACLY"
#   [111] "ACO2"                      "ACOT11"
#   [113] "ACOT13"                    "ACOT2"
#   [115] "ACOT4"                     "ACOT8"
#   [117] "ACOT9"                     "ACOX1"
#   [119] "ACOX3"                     "ACP1"
#   [121] "ACP2"                      "ACP5"
#   [123] "ACP6"                      "ACRBP"
#   [125] "ACSBG1"                    "ACSF2"
#   [127] "ACSF3"                     "ACSL3"
#   [129] "ACSL5"                     "ACSM2B"
#   [131] "ACSM3"                     "ACSM4"
#   [133] "ACSM5"                     "ACSM5P1"
#   [135] "ACSM6"                     "ACSS1"
#   [137] "ACSS3"                     "ACTB"
#   [139] "ACTG1"                     "ACTG1P21"
#   [141] "ACTL6A"                    "ACTN1"
#   [143] "ACTN4"                     "ACTR10"
#   [145] "ACTR1B"                    "ACTR2"
#   [147] "ACTR3"                     "ACTR3C"
#   [149] "ACTR6"                     "ACVR1B"
#   [151] "ACYP1"                     "ACYP2"
#   [153] "ADA2"                      "ADAD2"
#   [155] "ADAL"                      "ADAM10"
#   [157] "ADAM15"                    "ADAM17"
#   [159] "ADAM20P1"                  "ADAM28"
#   [161] "ADAM5"                     "ADAM7"
#   [163] "ADAM9"                     "ADAMTS10"
#   [165] "ADAMTS12"                  "ADAMTS14"
#   [167] "ADAMTS18"                  "ADAMTS4"
#   [169] "ADAMTS7P4"                 "ADAP2"
#   [171] "ADAR"                      "ADAT1"
#   [173] "ADAT2"                     "ADAT3"
#   [175] "ADCK5"                     "ADCY2"
#   [177] "ADCY3"                     "ADCY6"
#   [179] "ADCY9"                     "ADD1"
#   [181] "ADD3"                      "ADGB"
#   [183] "ADGRA2"                    "ADGRE2"
#   [185] "ADGRE5"                    "ADGRF1"
#   [187] "ADGRF5"                    "ADGRG1"
#   [189] "ADGRG7"                    "ADGRL1"
#   [191] "ADGRL2"                    "ADGRV1"
#   [193] "ADH1C"                     "ADH5"
#   [195] "ADH7"                      "ADHFE1"
#   [197] "ADI1"                      "ADIPOR1"
#   [199] "ADIRF"                     "ADK"
#   [201] "ADM"                       "ADNP"
#   [203] "ADNP-AS1"                  "ADNP2"
#   [205] "ADORA2B"                   "ADPGK"
#   [207] "ADPRH"                     "ADPRHL1"
#   [209] "ADPRM"                     "ADPRS"
#   [211] "ADRA1D"                    "ADRA2C"
#   [213] "ADRB1"                     "ADRB2"
#   [215] "ADRM1"                     "ADSL"
#   [217] "ADSS1"                     "ADSS2"
#   [219] "AEBP2"                     "AEN"
#   [221] "AFAP1"                     "AFAP1L1"
#   [223] "AFDN"                      "AFDN-DT"
#   [225] "AFF1"                      "AFF3"
#   [227] "AFF4"                      "AFG1L"
#   [229] "AFG3L1P"                   "AFG3L2"
#   [231] "AFMID"                     "AFTPH"
#   [233] "AGA"                       "AGAP1"
#   [235] "AGAP12P"                   "AGAP14P"
#   [237] "AGAP3"                     "AGAP4"
#   [239] "AGAP5"                     "AGAP6"
#   [241] "AGAP9"                     "AGBL1"
#   [243] "AGBL2"                     "AGBL3"
#   [245] "AGBL4"                     "AGBL5"
#   [247] "AGER"                      "AGFG1"
#   [249] "AGGF1"                     "AGGF1P5"
#   [251] "AGK-DT"                    "AGL"
#   [253] "AGO1"                      "AGO2"
#   [255] "AGO3"                      "AGO4"
#   [257] "AGPAT1"                    "AGPAT2"
#   [259] "AGPAT3"                    "AGPAT4"
#   [261] "AGPAT5"                    "AGPS"
#   [263] "AGR2"                      "AGR3"
#   [265] "AGRN"                      "AGTPBP1"
#   [267] "AGTRAP"                    "AGXT"
#   [269] "AHCTF1"                    "AHCY"
#   [271] "AHCYL1"                    "AHCYL2"
#   [273] "AHDC1"                     "AHI1"
#   [275] "AHNAK"                     "AHNAK2"
#   [277] "AHR"                       "AHRR"
#   [279] "AHSA1"                     "AHSA2P"
#   [281] "AIDA"                      "AIF1"
#   [283] "AIFM1"                     "AIFM2"
#   [285] "AIG1"                      "AIMP1"
#   [287] "AIMP1P1"                   "AIMP2"
#   [289] "AIP"                       "AJM1"
#   [291] "AK1"                       "AK2"
#   [293] "AK3"                       "AK6"
#   [295] "AK7"                       "AK8"
#   [297] "AK9"                       "AKAP1"
#   [299] "AKAP1-DT"                  "AKAP10"
#   [301] "AKAP11"                    "AKAP12"
#   [303] "AKAP13"                    "AKAP14"
#   [305] "AKAP17A"                   "AKAP6"
#   [307] "AKAP7"                     "AKAP8"
#   [309] "AKAP8L"                    "AKAP9"
#   [311] "AKIRIN1"                   "AKNA"
#   [313] "AKNAD1"                    "AKR1A1"
#   [315] "AKR1B1"                    "AKR1C1"
#   [317] "AKR1C2"                    "AKR1C3"
#   [319] "AKR7A2"                    "AKR7A3"
#   [321] "AKR7L"                     "AKT1"
#   [323] "AKT2"                      "AKTIP"
#   [325] "ALAD"                      "ALAS1"
#   [327] "ALB"                       "ALCAM"
#   [329] "ALDH16A1"                  "ALDH18A1"
#   [331] "ALDH1A1"                   "ALDH1A2"
#   [333] "ALDH1A3"                   "ALDH1L1"
#   [335] "ALDH1L1-AS1"               "ALDH1L2"
#   [337] "ALDH2"                     "ALDH3A1"
#   [339] "ALDH3A2"                   "ALDH3B1"
#   [341] "ALDH5A1"                   "ALDH7A1"
#   [343] "ALDH9A1"                   "ALDOA"
#   [345] "ALDOB"                     "ALDOC"
#   [347] "ALG1"                      "ALG10B"
#   [349] "ALG11"                     "ALG12"
#   [351] "ALG13"                     "ALG14"
#   [353] "ALG1L"                     "ALG5"
#   [355] "ALG6"                      "ALG8"
#   [357] "ALKBH2"                    "ALKBH3"
#   [359] "ALKBH5"                    "ALKBH7"
#   [361] "ALKBH8"                    "ALMS1"
#   [363] "ALMS1P1"                   "ALOX12-AS1"
#   [365] "ALOX12P2"                  "ALOX15"
#   [367] "ALOX15P1"                  "ALOX15P2"
#   [369] "ALPK1"                     "ALPK3"
#   [371] "ALPL"                      "ALS2"
#   [373] "ALS2CL"                    "ALYREF"
#   [375] "AMACR"                     "AMBRA1"
#   [377] "AMD1"                      "AMHR2"
#   [379] "AMMECR1"                   "AMMECR1L"
#   [381] "AMOT"                      "AMPD2"
#   [383] "AMPD3"                     "AMT"
#   [385] "AMY2B"                     "AMZ2"
#   [387] "AMZ2P1"                    "ANAPC1"
#   [389] "ANAPC10"                   "ANAPC11"
#   [391] "ANAPC13"                   "ANAPC15"
#   [393] "ANAPC16"                   "ANAPC2"
#   [395] "ANAPC4"                    "ANAPC5"
#   [397] "ANAPC7"                    "ANGEL1"
#   [399] "ANGEL2"                    "ANGPT1"
#   [401] "ANGPT4"                    "ANGPTL8"
#   [403] "ANK1"                      "ANK2"
#   [405] "ANK3"                      "ANKAR"
#   [407] "ANKDD1A"                   "ANKDD1B"
#   [409] "ANKEF1"                    "ANKFN1"
#   [411] "ANKFY1"                    "ANKHD1"
#   [413] "ANKHD1-EIF4EBP3"           "ANKIB1"
#   [415] "ANKK1"                     "ANKLE2"
#   [417] "ANKMY1"                    "ANKMY2"
#   [419] "ANKRA2"                    "ANKRD10"
#   [421] "ANKRD11"                   "ANKRD12"
#   [423] "ANKRD13A"                  "ANKRD13C"
#   [425] "ANKRD13D"                  "ANKRD16"
#   [427] "ANKRD17"                   "ANKRD18A"
#   [429] "ANKRD18B"                  "ANKRD20A1"
#   [431] "ANKRD20A11P"               "ANKRD20A4P"
#   [433] "ANKRD20A7P"                "ANKRD20A9P"
#   [435] "ANKRD22"                   "ANKRD23"
#   [437] "ANKRD26"                   "ANKRD27"
#   [439] "ANKRD28"                   "ANKRD30A"
#   [441] "ANKRD30B"                  "ANKRD31"
#   [443] "ANKRD33"                   "ANKRD35"
#   [445] "ANKRD36"                   "ANKRD36B"
#   [447] "ANKRD36BP2"                "ANKRD36C"
#   [449] "ANKRD37"                   "ANKRD39"
#   [451] "ANKRD40"                   "ANKRD40CL"
#   [453] "ANKRD42"                   "ANKRD44"
#   [455] "ANKRD44-AS1"               "ANKRD45"
#   [457] "ANKRD46"                   "ANKRD49"
#   [459] "ANKRD50"                   "ANKRD52"
#   [461] "ANKRD53"                   "ANKRD54"
#   [463] "ANKRD6"                    "ANKRD62"
#   [465] "ANKRD65"                   "ANKRD66"
#   [467] "ANKS1A"                    "ANKS3"
#   [469] "ANKS6"                     "ANKUB1"
#   [471] "ANKZF1"                    "ANLN"
#   [473] "ANO6"                      "ANO7L1"
#   [475] "ANO8"                      "ANP32A"
#   [477] "ANP32B"                    "ANP32BP1"
#   [479] "ANP32E"                    "ANPEP"
#   [481] "ANTXR2"                    "ANXA1"
#   [483] "ANXA11"                    "ANXA2"
#   [485] "ANXA3"                     "ANXA4"
#   [487] "ANXA5"                     "ANXA7"
#   [489] "AOPEP"                     "AP1AR"
#   [491] "AP1B1"                     "AP1G1"
#   [493] "AP1G2"                     "AP1M1"
#   [495] "AP1M2"                     "AP1S1"
#   [497] "AP1S3"                     "AP2A1"
#   [499] "AP2B1"                     "AP2M1"
#   [501] "AP2S1"                     "AP3B1"
#   [503] "AP3D1"                     "AP3M1"
#   [505] "AP3M2"                     "AP3S1"
#   [507] "AP3S2"                     "AP4B1"
#   [509] "AP4E1"                     "AP4M1"
#   [511] "AP4S1"                     "AP5B1"
#   [513] "AP5M1"                     "AP5Z1"
#   [515] "APBA1"                     "APBA3"
#   [517] "APBB2"                     "APC"
#   [519] "APCDD1"                    "APCDD1L-DT"
#   [521] "APEH"                      "APELA"
#   [523] "APEX1"                     "APH1A"
#   [525] "API5"                      "APIP"
#   [527] "APLF"                      "APLP2"
#   [529] "APMAP"                     "APOBEC3C"
#   [531] "APOBEC3D"                  "APOBEC3F"
#   [533] "APOBEC3G"                  "APOBEC4"
#   [535] "APOD"                      "APOF"
#   [537] "APOL1"                     "APOL2"
#   [539] "APOL4"                     "APOL6"
#   [541] "APOM"                      "APOO"
#   [543] "APOOL"                     "APOOP1"
#   [545] "APP"                       "APPBP2"
#   [547] "APPL1"                     "APPL2"
#   [549] "APRT"                      "APTR"
#   [551] "APTX"                      "AQP1"
#   [553] "AQP3"                      "AQP4"
#   [555] "AQP4-AS1"                  "AQP5"
#   [557] "AQP7"                      "AQR"
#   [559] "AR"                        "ARAF"
#   [561] "ARAP1"                     "ARAP2"
#   [563] "ARCN1"                     "AREL1"
#   [565] "ARF1"                      "ARF3"
#   [567] "ARF4"                      "ARF5"
#   [569] "ARF6"                      "ARFGAP1"
#   [571] "ARFGAP2"                   "ARFGAP3"
#   [573] "ARFGEF1"                   "ARFGEF2"
#   [575] "ARFGEF3"                   "ARFIP1"
#   [577] "ARFIP2"                    "ARFRP1"
#   [579] "ARGLU1"                    "ARHGAP12"
#   [581] "ARHGAP18"                  "ARHGAP21"
#   [583] "ARHGAP23"                  "ARHGAP24"
#   [585] "ARHGAP26"                  "ARHGAP27"
#   [587] "ARHGAP27P1-BPTFP1-KPNA2P3" "ARHGAP27P2"
#   [589] "ARHGAP32"                  "ARHGAP33"
#   [591] "ARHGAP35"                  "ARHGAP39"
#   [593] "ARHGAP4"                   "ARHGAP42"
#   [595] "ARHGAP42P4"                "ARHGAP44"
#   [597] "ARHGAP5"                   "ARHGAP6"
#   [599] "ARHGAP8"                   "ARHGDIB"
#   [601] "ARHGEF1"                   "ARHGEF10L"
#   [603] "ARHGEF11"                  "ARHGEF12"
#   [605] "ARHGEF17"                  "ARHGEF18"
#   [607] "ARHGEF19"                  "ARHGEF2"
#   [609] "ARHGEF26-AS1"              "ARHGEF28"
#   [611] "ARHGEF3"                   "ARHGEF33"
#   [613] "ARHGEF34P"                 "ARHGEF35-AS1"
#   [615] "ARHGEF37"                  "ARHGEF38"
#   [617] "ARHGEF4"                   "ARHGEF40"
#   [619] "ARHGEF5"                   "ARHGEF7"
#   [621] "ARID1A"                    "ARID1B"
#   [623] "ARID3A"                    "ARID4A"
#   [625] "ARID4B"                    "ARID5B"
#   [627] "ARIH1"                     "ARIH2"
#   [629] "ARIH2OS"                   "ARL1"
#   [631] "ARL10"                     "ARL13B"
#   [633] "ARL14EP"                   "ARL16"
#   [635] "ARL17B"                    "ARL2"
#   [637] "ARL2BP"                    "ARL3"
#   [639] "ARL4A"                     "ARL4AP5"
#   [641] "ARL4C"                     "ARL4D"
#   [643] "ARL5A"                     "ARL6"
#   [645] "ARL6IP1"                   "ARL6IP4"
#   [647] "ARL6IP5"                   "ARL6IP6"
#   [649] "ARL8A"                     "ARL8B"
#   [651] "ARL9"                      "ARMC1"
#   [653] "ARMC10"                    "ARMC2"
#   [655] "ARMC3"                     "ARMC6"
#   [657] "ARMC7"                     "ARMC8"
#   [659] "ARMC9"                     "ARMCX2"
#   [661] "ARMCX3"                    "ARMCX4"
#   [663] "ARMCX5"                    "ARMCX5-GPRASP2"
#   [665] "ARMH1"                     "ARMH3"
#   [667] "ARMH4"                     "ARNT"
#   [669] "ARNTL2"                    "ARPC1A"
#   [671] "ARPC1B"                    "ARPC2"
#   [673] "ARPC3"                     "ARPC3P4"
#   [675] "ARPC4"                     "ARPC5"
#   [677] "ARPC5L"                    "ARPIN"
#   [679] "ARPP19"                    "ARPP21"
#   [681] "ARRB1"                     "ARRB2"
#   [683] "ARRDC1"                    "ARRDC1-AS1"
#   [685] "ARRDC2"                    "ARRDC3"
#   [687] "ARRDC3-AS1"                "ARRDC4"
#   [689] "ARSA"                      "ARSD"
#   [691] "ARSD-AS1"                  "ARSG"
#   [693] "ARV1"                      "ARVCF"
#   [695] "ARX"                       "ASAH1"
#   [697] "ASAH2B"                    "ASAP2"
#   [699] "ASB13"                     "ASB14"
#   [701] "ASB3"                      "ASB4"
#   [703] "ASB7"                      "ASB8"
#   [705] "ASB9"                      "ASCC1"
#   [707] "ASCC2"                     "ASCC3"
#   [709] "ASDURF"                    "ASF1A"
#   [711] "ASF1B"                     "ASGR1"
#   [713] "ASGR2"                     "ASH1L"
#   [715] "ASH1L-AS1"                 "ASIC1"
#   [717] "ASIC3"                     "ASIC4"
#   [719] "ASL"                       "ASMTL"
#   [721] "ASMTL-AS1"                 "ASNS"
#   [723] "ASNSD1"                    "ASPA"
#   [725] "ASPH"                      "ASPSCR1"
#   [727] "ASRGL1"                    "ASS1"
#   [729] "ASS1P10"                   "ASTN1"
#   [731] "ASTN2"                     "ASXL1"
#   [733] "ASXL2"                     "ASZ1"
#   [735] "ATAD1"                     "ATAD2B"
#   [737] "ATAD3A"                    "ATAD3B"
#   [739] "ATAD3C"                    "ATAD5"
#   [741] "ATAT1"                     "ATE1"
#   [743] "ATE1-AS1"                  "ATF1"
#   [745] "ATF2"                      "ATF3"
#   [747] "ATF4"                      "ATF5"
#   [749] "ATF6"                      "ATF6B"
#   [751] "ATF7IP"                    "ATF7IP2"
#   [753] "ATG10"                     "ATG101"
#   [755] "ATG12"                     "ATG13"
#   [757] "ATG14"                     "ATG16L1"
#   [759] "ATG16L2"                   "ATG2A"
#   [761] "ATG2B"                     "ATG3"
#   [763] "ATG4A"                     "ATG4B"
#   [765] "ATG4C"                     "ATG5"
#   [767] "ATG7"                      "ATG9A"
#   [769] "ATG9B"                     "ATL1"
#   [771] "ATL2"                      "ATL3"
#   [773] "ATM"                       "ATMIN"
#   [775] "ATN1"                      "ATOX1"
#   [777] "ATP10A"                    "ATP10B"
#   [779] "ATP10D"                    "ATP11B"
#   [781] "ATP11C"                    "ATP12A"
#   [783] "ATP13A1"                   "ATP13A3"
#   [785] "ATP13A5"                   "ATP1A1"
#   [787] "ATP1A1-AS1"                "ATP1A2"
#   [789] "ATP1A3"                    "ATP1B1"
#   [791] "ATP1B3"                    "ATP23"
#   [793] "ATP2A1-AS1"                "ATP2A2"
#   [795] "ATP2A3"                    "ATP2B1"
#   [797] "ATP2B1-AS1"                "ATP2B3"
#   [799] "ATP2B4"                    "ATP2C1"
#   [801] "ATP2C2"                    "ATP2C2-AS1"
#   [803] "ATP5F1A"                   "ATP5F1B"
#   [805] "ATP5F1C"                   "ATP5F1D"
#   [807] "ATP5F1E"                   "ATP5IF1"
#   [809] "ATP5MC1"                   "ATP5MC2"
#   [811] "ATP5MC3"                   "ATP5ME"
#   [813] "ATP5MF"                    "ATP5MF-PTCD1"
#   [815] "ATP5MFP2"                  "ATP5MFP5"
#   [817] "ATP5MG"                    "ATP5MGL"
#   [819] "ATP5MJ"                    "ATP5MK"
#   [821] "ATP5PB"                    "ATP5PD"
#   [823] "ATP5PF"                    "ATP5PO"
#   [825] "ATP5POP1"                  "ATP6AP1L"
#   [827] "ATP6AP2"                   "ATP6V0A2"
#   [829] "ATP6V0A4"                  "ATP6V0B"
#   [831] "ATP6V0C"                   "ATP6V0D1"
#   [833] "ATP6V0D1-DT"               "ATP6V0D2"
#   [835] "ATP6V0E1"                  "ATP6V0E2"
#   [837] "ATP6V1A"                   "ATP6V1B2"
#   [839] "ATP6V1C1"                  "ATP6V1C2"
#   [841] "ATP6V1D"                   "ATP6V1E1"
#   [843] "ATP6V1F"                   "ATP6V1G1"
#   [845] "ATP7B"                     "ATP8A1"
#   [847] "ATP8A2"                    "ATP8B1"
#   [849] "ATP8B2"                    "ATP8B4"
#   [851] "ATP9A"                     "ATP9B"
#   [853] "ATPAF1"                    "ATPAF2"
#   [855] "ATPSCKMT"                  "ATR"
#   [857] "ATRAID"                    "ATRIP"
#   [859] "ATRN"                      "ATRX"
#   [861] "ATXN1"                     "ATXN10"
#   [863] "ATXN1L"                    "ATXN2"
#   [865] "ATXN2-AS"                  "ATXN2L"
#   [867] "ATXN3"                     "ATXN7"
#   [869] "ATXN7L1"                   "ATXN7L3"
#   [871] "ATXN7L3B"                  "AUH"
#   [873] "AUP1"                      "AURKA"
#   [875] "AURKAIP1"                  "AUTS2"
#   [877] "AVEN"                      "AVIL"
#   [879] "AXDND1"                    "AXIN1"
#   [881] "AZGP1"                     "AZI2"
#   [883] "AZIN1"                     "AZIN2"
#   [885] "B2M"                       "B3GALNT1"
#   [887] "B3GALNT2"                  "B3GALT4"
#   [889] "B3GALT5"                   "B3GALT5-AS1"
#   [891] "B3GALT9"                   "B3GAT3"
#   [893] "B3GNT2"                    "B3GNT3"
#   [895] "B3GNT5"                    "B3GNT7"
#   [897] "B3GNTL1"                   "B4GALNT3"
#   [899] "B4GALT1"                   "B4GALT3"
#   [901] "B4GALT4"                   "B4GALT5"
#   [903] "B4GALT7"                   "B4GAT1"
#   [905] "B9D1"                      "B9D2"
#   [907] "BAALC-AS1"                 "BAALC-AS2"
#   [909] "BABAM1"                    "BABAM2"
#   [911] "BACE1"                     "BACE1-AS"
#   [913] "BACE2"                     "BACH1"
#   [915] "BACH2"                     "BAD"
#   [917] "BAG1"                      "BAG2"
#   [919] "BAG3"                      "BAG4"
#   [921] "BAG5"                      "BAG6"
#   [923] "BAHCC1"                    "BAIAP2"
#   [925] "BAIAP2-DT"                 "BAIAP2L1"
#   [927] "BAIAP2L2"                  "BAIAP3"
#   [929] "BAK1"                      "BAMBI"
#   [931] "BANF1"                     "BANK1"
#   [933] "BANP"                      "BAP1"
#   [935] "BARX2"                     "BASP1"
#   [937] "BASP1-AS1"                 "BATF"
#   [939] "BATF2"                     "BAX"
#   [941] "BAZ1A"                     "BAZ1B"
#   [943] "BAZ2A"                     "BAZ2B"
#   [945] "BBC3"                      "BBIP1"
#   [947] "BBOF1"                     "BBOX1"
#   [949] "BBOX1-AS1"                 "BBS1"
#   [951] "BBS12"                     "BBS2"
#   [953] "BBS4"                      "BBS5"
#   [955] "BBS7"                      "BBS9"
#   [957] "BBX"                       "BCAM"
#   [959] "BCAN-AS1"                  "BCAP29"
#   [961] "BCAP31"                    "BCAR1"
#   [963] "BCAR3"                     "BCAS1"
#   [965] "BCAS2"                     "BCAS2P2"
#   [967] "BCAS3"                     "BCAS4"
#   [969] "BCAT2"                     "BCCIP"
#   [971] "BCDIN3D"                   "BCDIN3D-AS1"
#   [973] "BCKDHB"                    "BCKDK"
#   [975] "BCL10"                     "BCL11A"
#   [977] "BCL11B"                    "BCL2L1"
#   [979] "BCL2L11"                   "BCL2L12"
#   [981] "BCL2L13"                   "BCL2L14"
#   [983] "BCL2L15"                   "BCL2L2"
#   [985] "BCL2L2-PABPN1"             "BCL3"
#   [987] "BCL6"                      "BCL7A"
#   [989] "BCL7B"                     "BCL7C"
#   [991] "BCL9"                      "BCL9L"
#   [993] "BCLAF1"                    "BCLAF1P2"
#   [995] "BCLAF3"                    "BCO1"
#   [997] "BCO2"                      "BCOR"
#   [999] "BCR"                       "BCRP2"
#  [1001] "BCS1L"                     "BCYRN1"
#  [1003] "BDH1"                      "BDH2"
#  [1005] "BDKRB2"                    "BDNF-AS"
#  [1007] "BDP1"                      "BECN1"
#  [1009] "BEND3"                     "BEND3P1"
#  [1011] "BEND5"                     "BEND7"
#  [1013] "BEST2"                     "BEST4"
#  [1015] "BEX2"                      "BEX3"
#  [1017] "BEX4"                      "BHLHE40"
#  [1019] "BHLHE41"                   "BHMT2"
#  [1021] "BICC1"                     "BICD1"
#  [1023] "BICD2"                     "BICDL1"
#  [1025] "BICDL2"                    "BICRA"
#  [1027] "BICRAL"                    "BIK"
#  [1029] "BIN1"                      "BIN3"
#  [1031] "BIRC2"                     "BIRC3"
#  [1033] "BIRC5"                     "BIRC6"
#  [1035] "BIVM"                      "BLCAP"
#  [1037] "BLMH"                      "BLNK"
#  [1039] "BLOC1S1"                   "BLOC1S2"
#  [1041] "BLOC1S5"                   "BLOC1S6"
#  [1043] "BLVRA"                     "BLVRB"
#  [1045] "BLZF1"                     "BLZF2P"
#  [1047] "BMERB1"                    "BMF"
#  [1049] "BMI1"                      "BMP2K"
#  [1051] "BMP4"                      "BMP5"
#  [1053] "BMP7"                      "BMPR1A"
#  [1055] "BMPR1B"                    "BMPR1B-DT"
#  [1057] "BMPR2"                     "BMS1"
#  [1059] "BMS1P1"                    "BMS1P10"
#  [1061] "BMS1P2"                    "BMS1P21"
#  [1063] "BMS1P23"                   "BMS1P4"
#  [1065] "BMT2"                      "BNC2"
#  [1067] "BNIP1"                     "BNIP2"
#  [1069] "BNIP3"                     "BNIP3L"
#  [1071] "BNIPL"                     "BOD1"
#  [1073] "BOD1L1"                    "BOK"
#  [1075] "BOLA1"                     "BOLA3"
#  [1077] "BOLA3P3"                   "BOP1"
#  [1079] "BORA"                      "BORCS5"
#  [1081] "BORCS7"                    "BORCS8"
#  [1083] "BORCS8-MEF2B"              "BPGM"
#  [1085] "BPHL"                      "BPI"
#  [1087] "BPIFA1"                    "BPIFB1"
#  [1089] "BPNT1"                     "BPNT2"
#  [1091] "BPTF"                      "BRAF"
#  [1093] "BRAP"                      "BRAT1"
#  [1095] "BRCA1"                     "BRCA1P1"
#  [1097] "BRCA2"                     "BRCC3"
#  [1099] "BRD1"                      "BRD2"
#  [1101] "BRD3"                      "BRD3OS"
#  [1103] "BRD4"                      "BRD7"
#  [1105] "BRD8"                      "BRD9"
#  [1107] "BRF1"                      "BRF2"
#  [1109] "BRI3"                      "BRI3BP"
#  [1111] "BRIX1"                     "BRK1"
#  [1113] "BRMS1L"                    "BROX"
#  [1115] "BRPF1"                     "BRPF3"
#  [1117] "BRSK1"                     "BRWD1"
#  [1119] "BRWD1-AS2"                 "BRWD1P1"
#  [1121] "BRWD3"                     "BSCL2"
#  [1123] "BSDC1"                     "BSG"
#  [1125] "BSPRY"                     "BST1"
#  [1127] "BST2"                      "BTAF1"
#  [1129] "BTBD1"                     "BTBD16"
#  [1131] "BTBD2"                     "BTBD3"
#  [1133] "BTBD6"                     "BTBD7"
#  [1135] "BTBD8"                     "BTC"
#  [1137] "BTF3"                      "BTF3L4"
#  [1139] "BTF3P3"                    "BTG1"
#  [1141] "BTG2"                      "BTG3"
#  [1143] "BTG4"                      "BTN2A1"
#  [1145] "BTN2A2"                    "BTN3A1"
#  [1147] "BTN3A2"                    "BTN3A3"
#  [1149] "BTRC"                      "BUB3"
#  [1151] "BUD23"                     "BUD31"
#  [1153] "BZW1"                      "BZW2"
#  [1155] "C10orf67"                  "C10orf88"
#  [1157] "C10orf95"                  "C10orf95-AS1"
#  [1159] "C11orf1"                   "C11orf16"
#  [1161] "C11orf24"                  "C11orf49"
#  [1163] "C11orf52"                  "C11orf54"
#  [1165] "C11orf58"                  "C11orf65"
#  [1167] "C11orf71"                  "C11orf80"
#  [1169] "C11orf97"                  "C11orf98"
#  [1171] "C12orf29"                  "C12orf4"
#  [1173] "C12orf43"                  "C12orf45"
#  [1175] "C12orf57"                  "C12orf65"
#  [1177] "C12orf73"                  "C12orf75"
#  [1179] "C12orf76"                  "C14orf119"
#  [1181] "C14orf28"                  "C14orf39"
#  [1183] "C14orf93"                  "C15orf40"
#  [1185] "C15orf61"                  "C15orf65"
#  [1187] "C16orf46"                  "C16orf54"
#  [1189] "C16orf71"                  "C16orf72"
#  [1191] "C16orf74"                  "C16orf86"
#  [1193] "C16orf87"                  "C16orf91"
#  [1195] "C16orf97"                  "C17orf100"
#  [1197] "C17orf107"                 "C17orf49"
#  [1199] "C17orf58"                  "C17orf75"
#  [1201] "C17orf80"                  "C17orf97"
#  [1203] "C18orf21"                  "C18orf25"
#  [1205] "C18orf32"                  "C19orf12"
#  [1207] "C19orf18"                  "C19orf25"
#  [1209] "C19orf33"                  "C19orf44"
#  [1211] "C19orf48"                  "C19orf53"
#  [1213] "C1D"                       "C1GALT1"
#  [1215] "C1GALT1C1"                 "C1QB"
#  [1217] "C1QBP"                     "C1QTNF2"
#  [1219] "C1QTNF4"                   "C1QTNF5"
#  [1221] "C1QTNF8"                   "C1RL"
#  [1223] "C1orf109"                  "C1orf112"
#  [1225] "C1orf116"                  "C1orf122"
#  [1227] "C1orf131"                  "C1orf141"
#  [1229] "C1orf158"                  "C1orf159"
#  [1231] "C1orf167"                  "C1orf174"
#  [1233] "C1orf189"                  "C1orf194"
#  [1235] "C1orf21"                   "C1orf35"
#  [1237] "C1orf43"                   "C1orf50"
#  [1239] "C1orf52"                   "C1orf53"
#  [1241] "C1orf56"                   "C1orf74"
#  [1243] "C1orf87"                   "C2"
#  [1245] "C20orf194"                 "C20orf85"
#  [1247] "C20orf96"                  "C21orf58"
#  [1249] "C21orf62-AS1"              "C21orf91"
#  [1251] "C21orf91-OT1"              "C22orf15"
#  [1253] "C22orf23"                  "C22orf39"
#  [1255] "C22orf46"                  "C2CD2"
#  [1257] "C2CD2L"                    "C2CD3"
#  [1259] "C2CD5"                     "C2orf15"
#  [1261] "C2orf42"                   "C2orf49"
#  [1263] "C2orf49-DT"                "C2orf50"
#  [1265] "C2orf68"                   "C2orf73"
#  [1267] "C2orf74"                   "C2orf76"
#  [1269] "C2orf81"                   "C2orf92"
#  [1271] "C3"                        "C3orf18"
#  [1273] "C3orf33"                   "C3orf38"
#  [1275] "C3orf52"                   "C3orf62"
#  [1277] "C4orf19"                   "C4orf3"
#  [1279] "C4orf33"                   "C4orf36"
#  [1281] "C4orf47"                   "C5"
#  [1283] "C5AR1"                     "C5AR2"
#  [1285] "C5orf15"                   "C5orf24"
#  [1287] "C5orf38"                   "C5orf49"
#  [1289] "C5orf51"                   "C6orf118"
#  [1291] "C6orf120"                  "C6orf132"
#  [1293] "C6orf136"                  "C6orf163"
#  [1295] "C6orf226"                  "C6orf47"
#  [1297] "C6orf52"                   "C6orf62"
#  [1299] "C6orf89"                   "C7orf26"
#  [1301] "C7orf50"                   "C7orf57"
#  [1303] "C8orf31"                   "C8orf33"
#  [1305] "C8orf34"                   "C8orf37-AS1"
#  [1307] "C8orf44"                   "C8orf44-SGK3"
#  [1309] "C8orf76"                   "C8orf82"
#  [1311] "C8orf89"                   "C9orf106"
#  [1313] "C9orf116"                  "C9orf135"
#  [1315] "C9orf152"                  "C9orf16"
#  [1317] "C9orf24"                   "C9orf43"
#  [1319] "C9orf72"                   "C9orf78"
#  [1321] "C9orf85"                   "CA12"
#  [1323] "CA13"                      "CA14"
#  [1325] "CA5B"                      "CA5BP1"
#  [1327] "CA8"                       "CAAP1"
#  [1329] "CAB39"                     "CAB39L"
#  [1331] "CABCOCO1"                  "CABIN1"
#  [1333] "CABP4"                     "CACFD1"
#  [1335] "CACHD1"                    "CACNA1A"
#  [1337] "CACNA1D"                   "CACNA1E"
#  [1339] "CACNA1F"                   "CACNA2D2"
#  [1341] "CACNA2D3-AS1"              "CACNB2"
#  [1343] "CACNB3"                    "CACNB4"
#  [1345] "CACNG6"                    "CACNG8"
#  [1347] "CACUL1"                    "CACYBP"
#  [1349] "CAD"                       "CADM4"
#  [1351] "CADPS2"                    "CALB1"
#  [1353] "CALCOCO1"                  "CALCOCO2"
#  [1355] "CALD1"                     "CALHM1"
#  [1357] "CALHM6"                    "CALM1"
#  [1359] "CALM2"                     "CALM3"
#  [1361] "CALML4"                    "CALML6"
#  [1363] "CALR"                      "CALU"
#  [1365] "CAMK1D"                    "CAMK2D"
#  [1367] "CAMK2G"                    "CAMK4"
#  [1369] "CAMLG"                     "CAMSAP1"
#  [1371] "CAMSAP2"                   "CAMSAP3"
#  [1373] "CAMTA1"                    "CAMTA1-DT"
#  [1375] "CAND1"                     "CANT1"
#  [1377] "CANX"                      "CAP1"
#  [1379] "CAP2"                      "CAPN1"
#  [1381] "CAPN10"                    "CAPN10-DT"
#  [1383] "CAPN13"                    "CAPN14"
#  [1385] "CAPN15"                    "CAPN2"
#  [1387] "CAPN5"                     "CAPN6"
#  [1389] "CAPN7"                     "CAPN8"
#  [1391] "CAPN9"                     "CAPNS1"
#  [1393] "CAPRIN1"                   "CAPRIN2"
#  [1395] "CAPS"                      "CAPS2"
#  [1397] "CAPSL"                     "CAPZA1"
#  [1399] "CAPZA2"                    "CAPZB"
#  [1401] "CARD14"                    "CARD16"
#  [1403] "CARD19"                    "CARD6"
#  [1405] "CARD8"                     "CARF"
#  [1407] "CARHSP1"                   "CARM1"
#  [1409] "CARMIL1"                   "CARMN"
#  [1411] "CARNMT1"                   "CARS1"
#  [1413] "CARS2"                     "CASC15"
#  [1415] "CASC18"                    "CASC2"
#  [1417] "CASC3"                     "CASD1"
#  [1419] "CASK"                      "CASP1"
#  [1421] "CASP10"                    "CASP2"
#  [1423] "CASP3"                     "CASP4"
#  [1425] "CASP6"                     "CASP7"
#  [1427] "CASP8"                     "CASP8AP2"
#  [1429] "CASP9"                     "CAST"
#  [1431] "CASTOR2"                   "CASTOR3"
#  [1433] "CASZ1"                     "CAT"
#  [1435] "CATIP"                     "CATSPER2"
#  [1437] "CATSPER2P1"                "CATSPERD"
#  [1439] "CATSPERE"                  "CATSPERG"
#  [1441] "CAVIN3"                    "CBFA2T2"
#  [1443] "CBFB"                      "CBLB"
#  [1445] "CBLL1"                     "CBLL1P1"
#  [1447] "CBR1"                      "CBR3"
#  [1449] "CBR4"                      "CBWD1"
#  [1451] "CBWD2"                     "CBWD5"
#  [1453] "CBWD6"                     "CBX1"
#  [1455] "CBX3"                      "CBX3P7"
#  [1457] "CBX4"                      "CBX5"
#  [1459] "CBX5P1"                    "CBX6"
#  [1461] "CBX7"                      "CBX8"
#  [1463] "CBY1"                      "CC2D1A"
#  [1465] "CC2D2A"                    "CCAR1"
#  [1467] "CCAR2"                     "CCDC102A"
#  [1469] "CCDC102B"                  "CCDC103"
#  [1471] "CCDC106"                   "CCDC107"
#  [1473] "CCDC112"                   "CCDC113"
#  [1475] "CCDC115"                   "CCDC116"
#  [1477] "CCDC117"                   "CCDC11P1"
#  [1479] "CCDC12"                    "CCDC120"
#  [1481] "CCDC121"                   "CCDC122"
#  [1483] "CCDC124"                   "CCDC125"
#  [1485] "CCDC126"                   "CCDC127"
#  [1487] "CCDC13"                    "CCDC130"
#  [1489] "CCDC134"                   "CCDC137"
#  [1491] "CCDC138"                   "CCDC14"
#  [1493] "CCDC140"                   "CCDC142"
#  [1495] "CCDC144B"                  "CCDC144NL-AS1"
#  [1497] "CCDC146"                   "CCDC148"
#  [1499] "CCDC150"                   "CCDC152"
# ...
# [15915] "PRH2"                      "PRKAG2"
# [15917] "PRKAR1B-AS1"               "PRKCA"
# [15919] "PRKCB"                     "PRKCQ"
# [15921] "PRKN"                      "PRKY"
# [15923] "PRM2"                      "PROB1"
# [15925] "PROM2"                     "PROS2P"
# [15927] "PROX1-AS1"                 "PRR15L"
# [15929] "PRRC2A"                    "PRRX1"
# [15931] "PSAT1"                     "PSAT1P1"
# [15933] "PSG7"                      "PTCHD3"
# [15935] "PTGES"                     "PTGIS"
# [15937] "PTH2R"                     "PTPDC1"
# [15939] "PTPN7"                     "PTPRC"
# [15941] "PTPRH"                     "PTPRJ-AS1"
# [15943] "PTPRR"                     "PURG"
# [15945] "PWWP2AP1"                  "PXDN"
# [15947] "RAB3A"                     "RAB3C"
# [15949] "RAB8B"                     "RAC1P5"
# [15951] "RAF1P1"                    "RAI2"
# [15953] "RANBP9"                    "RAP1GAP2"
# [15955] "RAPGEF4"                   "RARG"
# [15957] "RASGRP3"                   "RASGRP3-AS1"
# [15959] "RASL11B"                   "RAX"
# [15961] "RBFOX1"                    "RBMS3-AS2"
# [15963] "RBMXL1"                    "RBMXL3"
# [15965] "RC3H2"                     "RCC2"
# [15967] "RCC2P7"                    "RCCD1-AS1"
# [15969] "RCVRN"                     "RDH16"
# [15971] "RDXP1"                     "REEP4"
# [15973] "RELA"                      "RFPL3S"
# [15975] "RFPL4AP1"                  "RFTN1P1"
# [15977] "RGS16"                     "RGS7BP"
# [15979] "RGS9"                      "RHBDF1"
# [15981] "RHOBTB2"                   "RIC1"
# [15983] "RIN3"                      "RN7SKP1"
# [15985] "RN7SKP122"                 "RN7SKP214"
# [15987] "RN7SKP30"                  "RN7SKP38"
# [15989] "RN7SKP95"                  "RN7SL165P"
# [15991] "RN7SL20P"                  "RN7SL294P"
# [15993] "RN7SL314P"                 "RN7SL380P"
# [15995] "RN7SL393P"                 "RN7SL415P"
# [15997] "RN7SL468P"                 "RN7SL471P"
# [15999] "RN7SL480P"                 "RN7SL513P"
# [16001] "RN7SL625P"                 "RN7SL674P"
# [16003] "RN7SL833P"                 "RNA5SP114"
# [16005] "RNA5SP280"                 "RNF128"
# [16007] "RNF139"                    "RNF150"
# [16009] "RNF182"                    "RNF217"
# [16011] "RNF26"                     "RNF43"
# [16013] "RNLS"                      "RNU2-49P"
# [16015] "RNU5F-2P"                  "RNU6-1174P"
# [16017] "RNU6-1205P"                "RNU6-222P"
# [16019] "RNU6-339P"                 "RNU6-451P"
# [16021] "RNU6-544P"                 "RNU6-625P"
# [16023] "RNU6-67P"                  "RNU6-899P"
# [16025] "RNU7-149P"                 "ROM1"
# [16027] "ROR2"                      "RPEP4"
# [16029] "RPL10P17"                  "RPL12P44"
# [16031] "RPL18AP2"                  "RPL21P121"
# [16033] "RPL21P37"                  "RPL23AP32"
# [16035] "RPL23AP59"                 "RPL23P5"
# [16037] "RPL24P8"                   "RPL27AP8"
# [16039] "RPL31P14"                  "RPL36P4"
# [16041] "RPL3P1"                    "RPL41P5"
# [16043] "RPL7AP52"                  "RPL7AP72"
# [16045] "RPL9P13"                   "RPL9P7"
# [16047] "RPS15AP27"                 "RPS17P14"
# [16049] "RPS24P18"                  "RPS26P42"
# [16051] "RPS2P32"                   "RPS2P4"
# [16053] "RPS2P45"                   "RPS3AP54"
# [16055] "RPS4XP16"                  "RPS4XP20"
# [16057] "RPS4Y1"                    "RSPO1"
# [16059] "RTBDN"                     "RTKN2"
# [16061] "RTL1"                      "RTL6"
# [16063] "RUBCNL"                    "RUNX2"
# [16065] "S100A8"                    "S1PR5"
# [16067] "SAG"                       "SAGE2P"
# [16069] "SAGE3P"                    "SAMD14"
# [16071] "SASS6"                     "SATL1"
# [16073] "SCAMP5"                    "SCD"
# [16075] "SCG2"                      "SCN1A"
# [16077] "SCN2A"                     "SCN3B"
# [16079] "SCN4A"                     "SCNN1G"
# [16081] "SEC14L4"                   "SEC23A-AS1"
# [16083] "SEC24A"                    "SEL1L3"
# [16085] "SELPLG"                    "SEMA5B"
# [16087] "SEMA6B"                    "SEMA6D"
# [16089] "SEPHS1P2"                  "SEPTIN4"
# [16091] "SEPTIN7P13"                "SERINC2"
# [16093] "SERPINB7"                  "SERPIND1"
# [16095] "SERPING1"                  "SERPINH1P1"
# [16097] "SERTM1"                    "SEZ6"
# [16099] "SFRP5"                     "SGF29"
# [16101] "SGIP1"                     "SGPP1"
# [16103] "SHANK3"                    "SHC4"
# [16105] "SHE"                       "SHISA7"
# [16107] "SHISA8"                    "SHISA9"
# [16109] "SIAH2-AS1"                 "SINHCAFP3"
# [16111] "SIPA1"                     "SIPA1L2"
# [16113] "SIRPB2"                    "SIT1"
# [16115] "SKI"                       "SKP1P2"
# [16117] "SLC17A6"                   "SLC17A7"
# [16119] "SLC23A4P"                  "SLC25A22"
# [16121] "SLC25A31"                  "SLC25A32"
# [16123] "SLC26A10"                  "SLC26A4"
# [16125] "SLC26A9"                   "SLC27A3"
# [16127] "SLC2A5"                    "SLC35A1"
# [16129] "SLC35F1"                   "SLC35F4"
# [16131] "SLC39A8"                   "SLC45A2"
# [16133] "SLC4A5"                    "SLC5A6"
# [16135] "SLC6A20"                   "SLC7A3"
# [16137] "SLC8A3"                    "SLC9B2"
# [16139] "SLCO1B3-SLCO1B7"           "SLCO2B1"
# [16141] "SLCO4A1"                   "SLCO5A1"
# [16143] "SMAD6"                     "SMARCE1P5"
# [16145] "SMCR2"                     "SMIM43"
# [16147] "SMN1"                      "SMTN"
# [16149] "SNCA-AS1"                  "SNHG1"
# [16151] "SNORA70"                   "SNPH"
# [16153] "SNRPA1P1"                  "SNX32"
# [16155] "SNX6P1"                    "SOCS7"
# [16157] "SORCS1"                    "SP140"
# [16159] "SP6"                       "SPATA22"
# [16161] "SPATA31D3"                 "SPDYA"
# [16163] "SPDYE20P"                  "SPIN4"
# [16165] "SPINK1"                    "SPON2"
# [16167] "SPRR1B"                    "SPRR2A"
# [16169] "SPRR3"                     "SPTA1"
# [16171] "SPTB"                      "SPTBN1-AS1"
# [16173] "SRP72P2"                   "SS18L1"
# [16175] "SSR4P1"                    "ST20"
# [16177] "ST3GAL1"                   "ST8SIA1"
# [16179] "ST8SIA4"                   "ST8SIA5-DT"
# [16181] "STAP1"                     "STIM2-AS1"
# [16183] "STIP1P3"                   "STK3"
# [16185] "STK32A"                    "STRC"
# [16187] "STX18-AS1"                 "STX19"
# [16189] "STXBP5"                    "STXBP6"
# [16191] "SUDS3P1"                   "SUMO3"
# [16193] "SUN3"                      "SVEP1"
# [16195] "SYNGR1"                    "SYNM"
# [16197] "SYNPO"                     "SYT2"
# [16199] "SYT4"                      "SYTL5"
# [16201] "TAB2"                      "TAB3-AS2"
# [16203] "TAF5"                      "TARM1"
# [16205] "TAS2R40"                   "TATDN2P3"
# [16207] "TBC1D30"                   "TBC1D8-AS1"
# [16209] "TBR1"                      "TBX4"
# [16211] "TCEA2"                     "TCEA3"
# [16213] "TCEAL2"                    "TCHH"
# [16215] "TCP11"                     "TDRD5"
# [16217] "TEAD3"                     "TENM1"
# [16219] "TENM3-AS1"                 "TESC"
# [16221] "TESMIN"                    "TET1"
# [16223] "TEX11"                     "TF"
# [16225] "TFAP2A"                    "TFAP2A-AS2"
# [16227] "TFCP2L1"                   "TGFB1"
# [16229] "TGFB1I1"                   "TGFBR2"
# [16231] "TGFBR3"                    "THAP3"
# [16233] "THBS3"                     "THOC5"
# [16235] "THRA1/BTR"                 "THRB-AS1"
# [16237] "THRIL"                     "THSD7B"
# [16239] "TICRR"                     "TIGD5"
# [16241] "TIMM9P3"                   "TLCD3A"
# [16243] "TLCD3B"                    "TLE6"
# [16245] "TLR10"                     "TLX2"
# [16247] "TMC8"                      "TMCO1-AS1"
# [16249] "TMEM100"                   "TMEM104"
# [16251] "TMEM134"                   "TMEM182"
# [16253] "TMEM183AP1"                "TMEM186"
# [16255] "TMEM265"                   "TMEM33"
# [16257] "TMEM63C"                   "TMEM71"
# [16259] "TMEM74"                    "TMEM75"
# [16261] "TMEM81"                    "TMEM86A"
# [16263] "TMPRSS9"                   "TMTC1"
# [16265] "TNFRSF10C"                 "TNFRSF9"
# [16267] "TNK2-AS1"                  "TNXB"
# [16269] "TOB1-AS1"                  "TOE1"
# [16271] "TOPAZ1"                    "TOR2A"
# [16273] "TPD52L1"                   "TPD52L3"
# [16275] "TPH2"                      "TPM3P1"
# [16277] "TPT1-AS1"                  "TPT1P3"
# [16279] "TRABD2A"                   "TRAF3IP3"
# [16281] "TRAV39"                    "TRBC2"
# [16283] "TRGC2"                     "TRHDE"
# [16285] "TRIM26BP"                  "TRIM36"
# [16287] "TRIM49"                    "TRIM51JP"
# [16289] "TRIM52-AS1"                "TRIM60"
# [16291] "TRIM60P14"                 "TRIM60P15"
# [16293] "TRPC3"                     "TRPC4"
# [16295] "TRPM3"                     "TSC22D2"
# [16297] "TSC22D4"                   "TSHZ3"
# [16299] "TSPAN5"                    "TSPYL4"
# [16301] "TTC9B"                     "TTLL1-AS1"
# [16303] "TTN"                       "TTPAL"
# [16305] "TTTY14"                    "TUBB1"
# [16307] "TUBB3P1"                   "TUBB8P3"
# [16309] "TUBB8P4"                   "TWF2"
# [16311] "TXN2"                      "TYMS"
# [16313] "TYROBP"                    "TYSND1"
# [16315] "U4"                        "UBA52P3"
# [16317] "UBASH3A"                   "UBE2Q2"
# [16319] "UBE2V1P13"                 "UBFD1"
# [16321] "UBOX5"                     "UCP1"
# [16323] "UGT1A6"                    "UMODL1"
# [16325] "UNC5C"                     "UNC5CL"
# [16327] "UNC80"                     "UNG"
# [16329] "UNGP3"                     "UPK1B"
# [16331] "USB1"                      "USH2A"
# [16333] "USP27X"                    "USP45"
# [16335] "VAMP1"                     "VAMP2"
# [16337] "VASH1-AS1"                 "VAT1L"
# [16339] "VDAC1P1"                   "VGF"
# [16341] "VKORC1"                    "VN1R28P"
# [16343] "VOPP1"                     "VPS50"
# [16345] "VSIG10L"                   "VSNL1"
# [16347] "VTI1BP4"                   "VWC2"
# [16349] "VWC2L"                     "WBP2NL"
# [16351] "WDR4"                      "WDR64"
# [16353] "WDR72"                     "WDR88"
# [16355] "WDR91"                     "WEE2"
# [16357] "WIPF3"                     "WNT5A"
# [16359] "WNT5B"                     "WT1"
# [16361] "WWC2-AS2"                  "WWTR1-IT1"
# [16363] "XKR5"                      "XKR8"
# [16365] "XXYLT1"                    "XYLT1"
# [16367] "ZACN"                      "ZAP70"
# [16369] "ZBP1"                      "ZBTB16"
# [16371] "ZBTB32"                    "ZBTB34"
# [16373] "ZBTB45"                    "ZBTB8A"
# [16375] "ZC3H12A"                   "ZCWPW2"
# [16377] "ZDHHC20P4"                 "ZDHHC8"
# [16379] "ZEB2"                      "ZFHX2-AS1"
# [16381] "ZFY"                       "ZIC5"
# [16383] "ZMYND15"                   "ZNF132"
# [16385] "ZNF136"                    "ZNF200"
# [16387] "ZNF319"                    "ZNF350-AS1"
# [16389] "ZNF358"                    "ZNF367"
# [16391] "ZNF382"                    "ZNF385D"
# [16393] "ZNF419"                    "ZNF502"
# [16395] "ZNF516-AS1"                "ZNF536"
# [16397] "ZNF554"                    "ZNF575"
# [16399] "ZNF579"                    "ZNF662"
# [16401] "ZNF668"                    "ZNF669"
# [16403] "ZNF680"                    "ZNF711"
# [16405] "ZNF722P"                   "ZNF735"
# [16407] "ZNF77"                     "ZNF778"
# [16409] "ZNF788P"                   "ZNF816"
# [16411] "ZNF823"                    "ZNF850"
# [16413] "ZP2"                       "ZSCAN22"

# %%
# Set the working directory
setwd("/media/asus/275dd380-2319-4638-bcdd-5f65b2b1d4b5/CHRF_Project_Data/Single_Cell/Honeycomb_Biotechnologies/Data_Analysis/3_Additional_Analysis_Resources/4_Seurat_Analysis_Tutorial")

# Source the local R script files
source("sc-type/R/gene_sets_prepare.R")
source("sc-type/R/sctype_score_.R")
source("sc-type/R/auto_detect_tissue_type.R")

# Make sure your Seurat object 'obj' is already loaded here
# If not, load or create your Seurat object 'obj'

# Scale the data in the Seurat object
# obj <- ScaleData(obj, features = rownames(obj@assays$RNA))

# Load the marker genes and predict the dataset's tissue type
db_ = "./ScTypeDB_full_v1.xlsx"
tissue_guess = auto_detect_tissue_type(path_to_db_file = db_, 
                                       seuratObject = obj, 
                                       scaled = TRUE, 
                                       assay = "RNA")
# Out:
# [1] "Checking...Pancreas"
# Warning message in checkGeneSymbols(markers_all):
# “Human gene symbols should be all upper-case except for the 'orf' in open reading frames. The case of some letters was corrected.”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Error in h(simpleError(msg, call)): error in evaluating the argument 'x' in selecting a method for function 'as.matrix': no slot of name "scale.data" for this object of class "Assay5"
# Traceback:
#
# 1. auto_detect_tissue_type(path_to_db_file = db_, seuratObject = obj,
#  .     scaled = TRUE, assay = "RNA")
# 2. as.matrix(seuratObject[[assay]]@scale.data)
# 3. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "no slot of name \"scale.data\" for this object of class \"Assay5\"",
#  .     base::quote(as.matrix(seuratObject[[assay]]@scale.data)))
# 4. h(simpleError(msg, call))

# %%
obj <- ScaleData(obj, features = rownames(obj))
# Out:
# Centering and scaling data matrix

# %%
## Download the reference scripts and mar
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/gene_sets_prepare.R")
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/sctype_score_.R")
source("https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/R/auto_detect_tissue_type.R")

# load the marker genes for all tissue types and have scType predict the right dataset
db_ = "https://raw.githubusercontent.com/IanevskiAleksandr/sc-type/master/ScTypeDB_full.xlsx";
tissue_guess = auto_detect_tissue_type(path_to_db_file = db_, 
                                       seuratObject = obj, 
                                       scaled = TRUE, 
                                       assay = "RNA")
# Out:
# [1] "Checking...Immune system"
# Warning message in checkGeneSymbols(markers_all):
# “Human gene symbols should be all upper-case except for the 'orf' in open reading frames. The case of some letters was corrected.”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Warning message in checkGeneSymbols(markers_all):
# “x contains non-approved gene symbols”
# Error in h(simpleError(msg, call)): error in evaluating the argument 'x' in selecting a method for function 'as.matrix': no slot of name "scale.data" for this object of class "Assay5"
# Traceback:
#
# 1. auto_detect_tissue_type(path_to_db_file = db_, seuratObject = obj,
#  .     scaled = TRUE, assay = "RNA")
# 2. as.matrix(seuratObject[[assay]]@scale.data)
# 3. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "no slot of name \"scale.data\" for this object of class \"Assay5\"",
#  .     base::quote(as.matrix(seuratObject[[assay]]@scale.data)))
# 4. h(simpleError(msg, call))

# %%
tissue<- tissue_guess[1,1]
# prepare gene sets
gs_list = gene_sets_prepare(db_, tissue)

es.max = sctype_score(scRNAseqData = obj[["RNA"]]@scale.data, 
                      scaled = TRUE, 
                      gs = gs_list$gs_positive, 
                      gs2 = gs_list$gs_negative) 

# merge by cluster
cL_resutls = do.call("rbind", lapply(unique(obj@meta.data$seurat_clusters), function(cl){
    es.max.cl = sort(rowSums(es.max[ ,rownames(obj@meta.data[obj@meta.data$seurat_clusters==cl, ])]), decreasing = !0)
    head(data.frame(cluster = cl, type = names(es.max.cl), scores = es.max.cl, ncells = sum(obj@meta.data$seurat_clusters==cl)), 10)
}))
sctype_scores = cL_resutls %>% group_by(cluster) %>% top_n(n = 1, wt = scores)  

# set low-confident (low ScType score) clusters to "unknown"
sctype_scores$type[as.numeric(as.character(sctype_scores$scores)) < sctype_scores$ncells/4] = "Unknown"
print(sctype_scores[,1:3])

# %%
# save old idents for reference
obj[["old.ident"]] <- Idents(object = obj)


obj@meta.data$customclassif = ""
        for(j in unique(sctype_scores$cluster)){
            cl_type = sctype_scores[sctype_scores$cluster==j,]; 
            obj@meta.data$customclassif[obj@meta.data$seurat_clusters == j] = as.character(cl_type$type[1])
        }
        
obj[["cell_type"]]<- obj$customclassif
write.table(sctype_scores, file = "sctype_scores.txt", quote = F, sep = "\t")

## Change the cell identity to "cell-type"
Idents(obj)<- obj$cell_type

## Visualise as umap
DimPlot(obj, reduction="umap", group.by = "cell_type")

# %%
## display a table of the results
datatable(sctype_scores)
Show 
10
 entriesSearch:

# %% [markdown]
# #### **1.6 Differential Gene Expression Analysis** ####
# The table below shows the the genes expressed in each cluster versus. all other clusters. You can change the Idents to change the grouping for the marker gene analysis.
#
# - > p_val: the p value from the Wilcoxon rank sum test
# - > avg_log2FC: log2 fold change
# - > pct.1: percent of cells expressing the indicated gene in the cluster specified in the “cluster” column
# - > pct.2: percent of all other cells in the other clusters that express the indicated gene
# - > p_val_adj: Bonferroni corrected p-values
# - > cluster: the specific cluster that is being evaluated

# %%
DefaultAssay(obj) <- "RNA"
Idents(obj)<- obj$seurat_clusters
markers <- FindAllMarkers(obj, 
                          logfc.threshold = 0.25,
                          test.use = "wilcox",
                          min.pct = 0.25)
datatable(markers)

# %% [markdown]
# #### **1.7 Save R environment** ####
# Consider saving your Seurat object and other variables for future use with the following code.

# %%
# Fill in the name of the data set below

save(obj, nGeneI, nTranI, sampleslsit, groupslist, totReads.df, markers, sctype_scores,
     file = "Name_of_Dataset.Rdata")
