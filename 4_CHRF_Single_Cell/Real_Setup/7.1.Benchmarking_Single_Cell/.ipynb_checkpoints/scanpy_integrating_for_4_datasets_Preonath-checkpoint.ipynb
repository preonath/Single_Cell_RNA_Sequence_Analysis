# %% [markdown]
# # **Integrating data using ingest and BBKNN**

# %% [markdown]
# The following tutorial describes a simple PCA-based method for integrating data we call [ingest](https://scanpy.readthedocs.io/en/latest/api/scanpy.tl.ingest.html) and compares it with [BBKNN](https://github.com/Teichlab/bbknn) [[Polanski19]](https://doi.org/10.1093/bioinformatics/btz625). BBKNN integrates well with the Scanpy workflow and is accessible through the [bbknn](https://scanpy.readthedocs.io/en/stable/external/scanpy.external.pp.bbknn.html) function.
#
# The [ingest](https://scanpy.readthedocs.io/en/latest/api/scanpy.tl.ingest.html) function assumes an annotated reference dataset that captures the biological variability of interest. The rational is to fit a model on the reference data and use it to project new data. For the time being, this model is a PCA combined with a neighbor lookup search tree, for which we use UMAP's implementation [[McInnes18]](https://arxiv.org/abs/1802.03426). Similar PCA-based integrations have been used before, for instance, in [[Weinreb18]](https://doi.org/10.1101/467886).
#
# * As [ingest](https://scanpy.readthedocs.io/en/latest/api/scanpy.tl.ingest.html) is simple and the procedure clear, the workflow is transparent and fast.
# * Like BBKNN, [ingest](https://scanpy.readthedocs.io/en/latest/api/scanpy.tl.ingest.html) leaves the data matrix itself invariant.
# * Unlike BBKNN, [ingest](https://scanpy.readthedocs.io/en/latest/api/scanpy.tl.ingest.html) solves the label mapping problem (like scmap) and maintains an embedding that might have desired properties like specific clusters or trajectories.
#
# We refer to this *asymmetric* dataset integration as *ingesting* annotations from an annotated reference `adata_ref` into an `adata` that still lacks this annotation. It is different from learning a joint representation that integrates datasets in a symmetric way as [BBKNN](https://github.com/Teichlab/bbknn), Scanorma, Conos, CCA (e.g. in Seurat) or a conditional VAE (e.g. in scVI, trVAE) would do, but comparable to the initiall MNN implementation in scran. Take a look at tools in the [external API](https://scanpy.readthedocs.io/en/latest/external/#data-integration) or at the [ecoystem page](https://scanpy.readthedocs.io/en/latest/ecosystem/#data-integration) to get a start with other tools.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns

# %%
sc.settings.verbosity = 1             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(3, 3), facecolor='white')
# Out:
# -----
# anndata     0.9.1
# scanpy      1.9.3
# -----
# PIL                 9.5.0
# asttokens           NA
# backcall            0.2.0
# colorama            0.4.6
# comm                0.1.3
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           5.1.1
# executing           1.2.0
# h5py                3.8.0
# igraph              0.10.4
# ipykernel           6.23.1
# ipywidgets          8.0.6
# jedi                0.18.2
# joblib              1.2.0
# kiwisolver          1.4.4
# leidenalg           0.9.1
# llvmlite            0.40.0
# louvain             0.8.0
# matplotlib          3.7.1
# mpl_toolkits        NA
# natsort             8.3.1
# numba               0.57.0
# numpy               1.24.3
# packaging           23.1
# pandas              2.0.1
# parso               0.8.3
# patsy               0.5.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.5.1
# prompt_toolkit      3.0.38
# psutil              5.9.5
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.15.1
# pyparsing           3.0.9
# pytz                2023.3
# scipy               1.10.1
# seaborn             0.12.2
# session_info        1.0.0
# setuptools          67.7.2
# six                 1.16.0
# sklearn             1.2.2
# stack_data          0.6.2
# statsmodels         0.14.0
# texttable           1.6.7
# threadpoolctl       3.1.0
# tornado             6.3.2
# traitlets           5.9.0
# typing_extensions   NA
# wcwidth             0.2.6
# zmq                 25.0.2
# zoneinfo            NA
# -----
# IPython             8.13.2
# jupyter_client      8.2.0
# jupyter_core        5.3.0
# -----
# Python 3.11.3 | packaged by conda-forge | (main, Apr  6 2023, 08:57:19) [GCC 11.3.0]
# Linux-5.15.0-86-generic-x86_64-with-glibc2.35
# -----
# Session information updated at 2023-10-11 12:51

# %% [markdown]
# ## **PBMCs**

# %% [markdown]
# We consider an annotated reference dataset `adata_ref` and a dataset for which you want to query labels and embeddings `adata`.

# %%
adata1 = sc.read_h5ad('./data/merged_4_dataset/Longitudinal_profiling_of_respiratory_and_systemic_immune_responses_reveals_myeloid_cell_driven_lung_inflammation_in_severe_COVID_19.h5ad')
adata2 = sc.read_h5ad('./data/merged_4_dataset/SARS_CoV_2_receptor_ACE2_and_TMPRSS2_are_primarily_expressed_in_bronchial_transient_secretory_cells.h5ad')
adata3 = sc.read_h5ad('./data/merged_4_dataset/Impaired_local_intrinsic_immunity_to_SARS_CoV_2_infection_in_severe_COVID_19.h5ad')
adata4 = sc.read_h5ad('./data/merged_4_dataset/Local_and_systemic_responses_to_SARS_CoV_2_infection_in_children_and_adults.h5ad')

# %%
# Find common genes
common_genes = (
    adata1.var_names.intersection(adata2.var_names)
    .intersection(adata3.var_names)
    .intersection(adata4.var_names)
)

# Subset data to common genes
adata1 = adata1[:, common_genes]
adata2 = adata2[:, common_genes]
adata3 = adata3[:, common_genes]
adata4 = adata4[:, common_genes]

# %%
display(adata1)
display(adata2)
display(adata3)
display(adata4)
# Out:
# View of AnnData object with n_obs × n_vars = 3434 × 20925
#     obs: 'donor_id', 'author_cell_type', 'days_post_intubation', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_umap'
# View of AnnData object with n_obs × n_vars = 17451 × 20925
#     obs: 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'CellType', 'smoking', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'donor_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_umap'
# View of AnnData object with n_obs × n_vars = 32588 × 20925
#     obs: 'donor_id', 'Peak_Respiratory_Support_WHO_Score', 'Bloody_Swab', 'Percent_Mitochondrial', 'SARSCoV2_PCR_Status', 'SARSCoV2_PCR_Status_and_WHO_Score', 'Cohort_Disease_WHO_Score', 'biosample_id', 'SingleCell_SARSCoV2_RNA_Status', 'SARSCoV2_Unspliced_TRS_Total_Corrected', 'SARSCoV2_Spliced_TRS_Total_Corrected', 'SARSCoV2_NegativeStrand_Total_Corrected', 'SARSCoV2_PositiveStrand_Total_Corrected', 'SARSCoV2_Total_Corrected', 'Coarse_Cell_Annotations', 'Detailed_Cell_Annotations', 'Annotation', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'mvp.mean', 'mvp.dispersion', 'mvp.dispersion.scaled', 'mvp.variable', 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_pca', 'X_umap'
# View of AnnData object with n_obs × n_vars = 236977 × 20925
#     obs: 'sample_id', 'donor_id', 'Group', 'Ethnicity_inferred', 'Smoker', 'COVID_status', 'COVID_severity', 'First_symptoms_hospitalisation_interval', 'First_symptoms_collection_interval', 'Positive_test_collection_interval', 'Kit_version', 'dataset', 'batch', 'Cell_type_annotation_level3', 'Cell_type_annotation_level1', 'Cell_type_annotation_level2', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'percent_ribo', 'n_counts_total_sarscov2', 'percent_total_sarscov2', 'n_counts_sarscov2', 'percent_sarscov2', 'scrublet_score', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage'
#     var: 'mito', 'ribo', 'sarscov2', 'gene_symbols', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: 'cell_type_colors', 'default_embedding', 'schema_version', 'title'
#     obsm: 'X_umap'

# %% [markdown]
# ### **adata1** ###

# %%
display(adata1.obs.head(3))
display(adata1.var.head(3))


print("\nUMAP visualization of the data:")
sc.pl.umap(adata1)
# Out:
#                  donor_id author_cell_type days_post_intubation
# index
# AAACCCACAAGTGCAG   COV028       neutrophil                    3  \
# AAACCCACACGAGGAT   COV028          myeloid                    3
# AAACCCAGTACGGTTT   COV028          myeloid                    3
#
#                  assay_ontology_term_id cell_type_ontology_term_id
# index
# AAACCCACAAGTGCAG            EFO:0009922                 CL:0000775  \
# AAACCCACACGAGGAT            EFO:0009922                 CL:0000763
# AAACCCAGTACGGTTT            EFO:0009922                 CL:0000763
#
#                  development_stage_ontology_term_id disease_ontology_term_id
# index
# AAACCCACAAGTGCAG                     HsapDv:0000160            MONDO:0100096  \
# AAACCCACACGAGGAT                     HsapDv:0000160            MONDO:0100096
# AAACCCAGTACGGTTT                     HsapDv:0000160            MONDO:0100096
#
#                  self_reported_ethnicity_ontology_term_id  is_primary_data
# index
# AAACCCACAAGTGCAG                                  unknown             True  \
# AAACCCACACGAGGAT                                  unknown             True
# AAACCCAGTACGGTTT                                  unknown             True
#
#                  organism_ontology_term_id  ... tissue_ontology_term_id
# index                                       ...
# AAACCCACAAGTGCAG            NCBITaxon:9606  ...          UBERON:0001005  \
# AAACCCACACGAGGAT            NCBITaxon:9606  ...          UBERON:0001005
# AAACCCAGTACGGTTT            NCBITaxon:9606  ...          UBERON:0001005
#
#                  suspension_type cell_type      assay   disease      organism
# index
# AAACCCACAAGTGCAG            cell       NaN  10x 3' v3  COVID-19  Homo sapiens  \
# AAACCCACACGAGGAT            cell       NaN  10x 3' v3  COVID-19  Homo sapiens
# AAACCCAGTACGGTTT            cell       NaN  10x 3' v3  COVID-19  Homo sapiens
#
#                      sex              tissue self_reported_ethnicity
# index
# AAACCCACAAGTGCAG  female  respiratory airway                 unknown  \
# AAACCCACACGAGGAT  female  respiratory airway                 unknown
# AAACCCAGTACGGTTT  female  respiratory airway                 unknown
#
#                         development_stage
# index
# AAACCCACAAGTGCAG  66-year-old human stage
# AAACCCACACGAGGAT  66-year-old human stage
# AAACCCAGTACGGTTT  66-year-old human stage
#
# [3 rows x 21 columns]
#                 gene_symbols  feature_is_filtered feature_name
# ENSG00000000003       TSPAN6                False       TSPAN6  \
# ENSG00000000419         DPM1                False         DPM1
# ENSG00000000457        SCYL3                False        SCYL3
#
#                 feature_reference feature_biotype
# ENSG00000000003    NCBITaxon:9606            gene
# ENSG00000000419    NCBITaxon:9606            gene
# ENSG00000000457    NCBITaxon:9606            gene
# UMAP visualization of the data:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(

# %% [markdown]
# ### **adata2** ###

# %% [markdown]
# ### **adata3** ###

# %% [markdown]
# ### **adata4** ###

# %%
common_genes = adata1.var_names.intersection(adata2.var_names)
adata1 = adata1[:, common_genes]
adata2 = adata2[:, common_genes]
# Displaying common genes
common_genes.tolist()[:10], len(common_genes)  # Displaying first 10 common genes and total count for brevity
print(len(common_genes))
# Out:
# 20987

# %%
# Intersect genes between the two datasets
common_genes = adata_ref.var.index.intersection(adata.var.index)

# Subset datasets to only include common genes
adata_ref = adata_ref[:, common_genes]
adata = adata[:, common_genes]

# Convert to dataframes
df_ref = pd.DataFrame(adata_ref.X.todense(), index=adata_ref.obs.index, columns=common_genes)
df = pd.DataFrame(adata.X.todense(), index=adata.obs.index, columns=common_genes)

# Display the first few rows of each dataframe
print(df_ref.head())
print(df.head())
# Out:
#                   ENSG00000000003  ENSG00000000419  ENSG00000000457
# index
# AAACCCACAAGTGCAG              0.0         0.000000              0.0  \
# AAACCCACACGAGGAT              0.0         5.924847              0.0
# AAACCCAGTACGGTTT              0.0         0.000000              0.0
# AAACCCATCCCGAAAT              0.0         0.000000              0.0
# AAACCCATCCTCGATC              0.0         0.000000              0.0
#
#                   ENSG00000000460  ENSG00000000938  ENSG00000000971
# index
# AAACCCACAAGTGCAG              0.0         0.000000              0.0  \
# AAACCCACACGAGGAT              0.0         7.493890              0.0
# AAACCCAGTACGGTTT              0.0         0.000000              0.0
# AAACCCATCCCGAAAT              0.0        10.618243              0.0
# AAACCCATCCTCGATC              0.0         0.000000              0.0
#
#                   ENSG00000001036  ENSG00000001084  ENSG00000001167
# index
# AAACCCACAAGTGCAG         0.000000              0.0              0.0  \
# AAACCCACACGAGGAT         5.924847              0.0              0.0
# AAACCCAGTACGGTTT         0.000000              0.0              0.0
# AAACCCATCCCGAAAT         0.000000              0.0              0.0
# AAACCCATCCTCGATC         0.000000              0.0              0.0
#
#                   ENSG00000001460  ...  ENSG00000273464  ENSG00000273472
# index                              ...
# AAACCCACAAGTGCAG         0.000000  ...              0.0              0.0  \
# AAACCCACACGAGGAT         0.000000  ...              0.0              0.0
# AAACCCAGTACGGTTT         0.000000  ...              0.0              0.0
# AAACCCATCCCGAAAT         8.299982  ...              0.0              0.0
# AAACCCATCCTCGATC         0.000000  ...              0.0              0.0
#
#                   ENSG00000273474  ENSG00000273481  ENSG00000273483
# index
# AAACCCACAAGTGCAG              0.0              0.0              0.0  \
# AAACCCACACGAGGAT              0.0              0.0              0.0
# AAACCCAGTACGGTTT              0.0              0.0              0.0
# AAACCCATCCCGAAAT              0.0              0.0              0.0
# AAACCCATCCTCGATC              0.0              0.0              0.0
#
#                   ENSG00000273485  ENSG00000273486  ENSG00000273487
# index
# AAACCCACAAGTGCAG              0.0              0.0              0.0  \
# AAACCCACACGAGGAT              0.0              0.0              0.0
# AAACCCAGTACGGTTT              0.0              0.0              0.0
# AAACCCATCCCGAAAT              0.0              0.0              0.0
# AAACCCATCCTCGATC              0.0              0.0              0.0
#
#                   ENSG00000273489  ENSG00000273492
# index
# AAACCCACAAGTGCAG              0.0              0.0
# AAACCCACACGAGGAT              0.0              0.0
# AAACCCAGTACGGTTT              0.0              0.0
# AAACCCATCCCGAAAT              0.0              0.0
# AAACCCATCCTCGATC              0.0              0.0
#
# [5 rows x 20987 columns]
#                        ENSG00000000003  ENSG00000000419  ENSG00000000457
# index
# p46c_AAACCTGAGACCCACC         0.623530         1.672883              0.0  \
# p46c_AAACCTGAGGACACCA         1.131887         1.131887              0.0
# p46c_AAACCTGAGTAACCCT         1.024848         1.024848              0.0
# p46c_AAACCTGGTCATCGGC         0.000000         0.000000              0.0
# p46c_AAACCTGTCACCCGAG         0.941555         0.000000              0.0
#
#                        ENSG00000000460  ENSG00000000938  ENSG00000000971
# index
# p46c_AAACCTGAGACCCACC              0.0              0.0         0.623530  \
# p46c_AAACCTGAGGACACCA              0.0              0.0         1.423651
# p46c_AAACCTGAGTAACCCT              0.0              0.0         2.097611
# p46c_AAACCTGGTCATCGGC              0.0              0.0         0.000000
# p46c_AAACCTGTCACCCGAG              0.0              0.0         0.941555
#
#                        ENSG00000001036  ENSG00000001084  ENSG00000001167
# index
# p46c_AAACCTGAGACCCACC         0.623530         0.000000              0.0  \
# p46c_AAACCTGAGGACACCA         0.000000         0.000000              0.0
# p46c_AAACCTGAGTAACCCT         1.520244         0.000000              0.0
# p46c_AAACCTGGTCATCGGC         1.653408         0.000000              0.0
# p46c_AAACCTGTCACCCGAG         0.941555         0.941555              0.0
#
#                        ENSG00000001460  ...  ENSG00000273464  ENSG00000273472
# index                                   ...
# p46c_AAACCTGAGACCCACC         0.000000  ...              0.0              0.0  \
# p46c_AAACCTGAGGACACCA         0.000000  ...              0.0              0.0
# p46c_AAACCTGAGTAACCCT         0.000000  ...              0.0              0.0
# p46c_AAACCTGGTCATCGGC         0.000000  ...              0.0              0.0
# p46c_AAACCTGTCACCCGAG         0.941555  ...              0.0              0.0
#
#                        ENSG00000273474  ENSG00000273481  ENSG00000273483
# index
# p46c_AAACCTGAGACCCACC              0.0              0.0              0.0  \
# p46c_AAACCTGAGGACACCA              0.0              0.0              0.0
# p46c_AAACCTGAGTAACCCT              0.0              0.0              0.0
# p46c_AAACCTGGTCATCGGC              0.0              0.0              0.0
# p46c_AAACCTGTCACCCGAG              0.0              0.0              0.0
#
#                        ENSG00000273485  ENSG00000273486  ENSG00000273487
# index
# p46c_AAACCTGAGACCCACC              0.0              0.0              0.0  \
# p46c_AAACCTGAGGACACCA              0.0              0.0              0.0
# p46c_AAACCTGAGTAACCCT              0.0              0.0              0.0
# p46c_AAACCTGGTCATCGGC              0.0              0.0              0.0
# p46c_AAACCTGTCACCCGAG              0.0              0.0              0.0
#
#                        ENSG00000273489  ENSG00000273492
# index
# p46c_AAACCTGAGACCCACC              0.0              0.0
# p46c_AAACCTGAGGACACCA              0.0              0.0
# p46c_AAACCTGAGTAACCCT              0.0              0.0
# p46c_AAACCTGGTCATCGGC              0.0              0.0
# p46c_AAACCTGTCACCCGAG              0.0              0.0
#
# [5 rows x 20987 columns]

# %% [markdown]
# To use `sc.tl.ingest`, the datasets need to be defined on the same variables.

# %%
var_names = adata_ref.var_names.intersection(adata.var_names)
adata_ref = adata_ref[:, var_names]
adata = adata[:, var_names]

# %% [markdown]
# The model and graph (here PCA, neighbors, UMAP) trained on the reference data will explain the biological variation observed within it.

# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='umap')

# %%
sc.pp.pca(adata_ref)
sc.pp.neighbors(adata_ref)
sc.tl.umap(adata_ref)

# %% [markdown]
# The manifold still looks essentially the same as in the [clustering tutorial](https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html).

# %%
sc.tl.louvain(adata_ref)

# %%
sc.pl.umap(adata_ref, color='louvain')
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### **Mapping PBMCs using ingest**

# %% [markdown]
# Let's map labels and embeddings from `adata_ref` to `adata` based on a chosen representation. Here, we use `adata_ref.obsm['X_pca']` to map cluster labels and the UMAP coordinates.

# %%
sc.tl.ingest(adata, adata_ref, obs='louvain')

adata.uns['louvain_colors'] = adata_ref.uns['louvain_colors']  # fix colors

print(adata.obs.columns)

# Check if 'bulk_labels' exists in adata_ref.obs
if 'bulk_labels' in adata_ref.obs.columns:
    # Ingest the data from adata_ref to adata
    sc.tl.ingest(adata, adata_ref, obs='louvain')

    # Update the color schemes for the louvain clusters
    adata.uns['louvain_colors'] = adata_ref.uns['louvain_colors']

    # Visualize using UMAP
    sc.pl.umap(adata, color=['louvain', 'bulk_labels'], wspace=0.5)
else:
    print("'bulk_labels' not found in adata_ref. Visualizing only with 'louvain' clusters.")
    sc.pl.umap(adata, color='louvain')
# Out:
# Index(['nCount_RNA', 'nFeature_RNA', 'percent.mt', 'CellType', 'smoking',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'sex_ontology_term_id',
#        'tissue_ontology_term_id', 'donor_id', 'suspension_type', 'cell_type',
#        'assay', 'disease', 'organism', 'sex', 'tissue',
#        'self_reported_ethnicity', 'development_stage', 'louvain'],
#       dtype='object')
# 'bulk_labels' not found in adata_ref. Visualizing only with 'louvain' clusters.
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# By comparing the 'bulk_labels' annotation with 'louvain', we see that the data has been reasonably mapped, only the annotation of dendritic cells seems ambiguous and might have been ambiiguous in `adata` already.

# %%
adata_concat = adata_ref.concatenate(adata, batch_categories=['ref', 'new'])
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(

# %%
adata_concat.obs.louvain = adata_concat.obs.louvain.astype('category')
adata_concat.obs.louvain = adata_concat.obs.louvain.cat.reorder_categories(adata_ref.obs.louvain.cat.categories)  # fix category ordering
adata_concat.uns['louvain_colors'] = adata_ref.uns['louvain_colors']  # fix category colors

# %%
sc.pl.umap(adata_concat, color=['batch', 'louvain'])
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# While there seems to be some batch-effect in the monocytes and dendritic cell clusters, the new data is otherwise mapped relatively homogeneously.
#
# The megakaryoctes are only present in `adata_ref` and no cells from `adata` map onto them. If interchanging reference data and query data, Megakaryocytes do not appear as a separate cluster anymore. This is an extreme case as the reference data is very small; but one should always question if the reference data contain enough biological variation to meaningfully accomodate query data.

# %% [markdown]
# ### **Using BBKNN**

# %%
sc.tl.pca(adata_concat)

# %%
# %%time
sc.external.pp.bbknn(adata_concat, batch_key='batch')  # running bbknn 1.3.6
# Out:
# WARNING: consider updating your call to make use of `computation`
# CPU times: user 742 ms, sys: 1.04 ms, total: 743 ms
# Wall time: 742 ms

# %%
sc.tl.umap(adata_concat)

# %%
sc.pl.umap(adata_concat, color=['batch', 'louvain'])
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# Also BBKNN doesn't maintain the Megakaryocytes cluster. However, it seems to mix cells more homogeneously.

# %% [markdown]
# ## **Pancreas**

# %% [markdown]
# The following data has been used in the scGen paper [[Lotfollahi19]](https://doi.org/10.1038/s41592-019-0494-8), has been used [here](https://nbviewer.jupyter.org/github/M0hammadL/scGen_notebooks/blob/master/notebooks/scgen_batch_removal.ipynb), was curated [here](https://nbviewer.jupyter.org/github/Teichlab/bbknn/blob/master/examples/pancreas.ipynb) and can be downloaded from [here (the BBKNN paper)](ftp://ngs.sanger.ac.uk/production/teichmann/BBKNN/objects-pancreas.zip).
#
# It contains data for human pancreas from 4 different studies (Segerstolpe16, Baron16, Wang16, Muraro16), which have been used in the seminal papers on single-cell dataset integration (Butler18, Haghverdi18) and many times ever since.

# %%
# note that this collection of batches is already intersected on the genes
# adata_all = sc.read('data/pancreas.h5ad', backup_url='https://www.dropbox.com/s/qj1jlm9w10wmt0u/pancreas.h5ad?dl=1')
# Out:
#   0%|          | 0.00/176M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 # note that this collection of batches is already intersected on the genes
# ----> 2 adata_all = sc.read('data/pancreas.h5ad', backup_url='https://www.dropbox.com/s/qj1jlm9w10wmt0u/pancreas.h5ad?dl=1')
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/readwrite.py:112, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     110 filename = Path(filename)  # allow passing strings
#     111 if is_valid_filename(filename):
# --> 112     return _read(
#     113         filename,
#     114         backed=backed,
#     115         sheet=sheet,
#     116         ext=ext,
#     117         delimiter=delimiter,
#     118         first_column_names=first_column_names,
#     119         backup_url=backup_url,
#     120         cache=cache,
#     121         cache_compression=cache_compression,
#     122         **kwargs,
#     123     )
#     124 # generate filename and read to dict
#     125 filekey = str(filename)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/readwrite.py:716, in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     714 else:
#     715     ext = is_valid_filename(filename, return_ext=True)
# --> 716 is_present = _check_datafile_present_and_download(filename, backup_url=backup_url)
#     717 if not is_present:
#     718     logg.debug(f'... did not find original file {filename}')
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/readwrite.py:1002, in _check_datafile_present_and_download(path, backup_url)
#     999     logg.info(f'creating directory {path.parent}/ for saving data')
#    1000     path.parent.mkdir(parents=True)
# -> 1002 _download(backup_url, path)
#    1003 return True
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/readwrite.py:977, in _download(url, path)
#     975                 f.write(block)
#     976                 blocknum += 1
# --> 977                 t.update(len(block))
#     978                 block = resp.read(blocksize)
#     980 except (KeyboardInterrupt, Exception):
#     981     # Make sure file doesn’t exist half-downloaded
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/tqdm/notebook.py:266, in tqdm_notebook.update(self, n)
#     264 def update(self, n=1):
#     265     try:
# --> 266         return super(tqdm_notebook, self).update(n=n)
#     267     # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     268     except:  # NOQA
#     269         # cannot catch KeyboardInterrupt when using manual tqdm
#     270         # as the interrupt will most likely happen on another statement
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/tqdm/std.py:1239, in tqdm.update(self, n)
#    1237     self._ema_dn(dn)
#    1238     self._ema_dt(dt)
# -> 1239 self.refresh(lock_args=self.lock_args)
#    1240 if self.dynamic_miniters:
#    1241     # If no `miniters` was specified, adjust automatically to the
#    1242     # maximum iteration rate seen so far between two prints.
#    1243     # e.g.: After running `tqdm.update(5)`, subsequent
#    1244     # calls to `tqdm.update()` will only cause an update after
#    1245     # at least 5 more iterations.
#    1246     if self.maxinterval and dt >= self.maxinterval:
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/tqdm/std.py:1344, in tqdm.refresh(self, nolock, lock_args)
#    1342     else:
#    1343         self._lock.acquire()
# -> 1344 self.display()
#    1345 if not nolock:
#    1346     self._lock.release()
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/tqdm/notebook.py:175, in tqdm_notebook.display(self, msg, pos, close, bar_style, check_delay)
#     173     # never clear the bar (signal: msg='')
#     174     if right:
# --> 175         rtext.value = right
#     177 # Change bar style
#     178 if bar_style:
#     179     # Hack-ish way to avoid the danger bar_style being overridden by
#     180     # success because the bar gets closed after the error...
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/traitlets/traitlets.py:732, in TraitType.__set__(self, obj, value)
#     730     raise TraitError('The "%s" trait is read-only.' % self.name)
#     731 else:
# --> 732     self.set(obj, value)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/traitlets/traitlets.py:721, in TraitType.set(self, obj, value)
#     717     silent = False
#     718 if silent is not True:
#     719     # we explicitly compare silent to True just in case the equality
#     720     # comparison above returns something other than True/False
# --> 721     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/traitlets/traitlets.py:1505, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1504 def _notify_trait(self, name, old_value, new_value):
# -> 1505     self.notify_change(
#    1506         Bunch(
#    1507             name=name,
#    1508             old=old_value,
#    1509             new=new_value,
#    1510             owner=self,
#    1511             type="change",
#    1512         )
#    1513     )
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:700, in Widget.notify_change(self, change)
#     696 if self.comm is not None and getattr(self.comm, 'kernel', True) is not None:
#     697     # Make sure this isn't information that the front-end just sent us.
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
# --> 700         self.send_state(key=name)
#     701 super().notify_change(change)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:586, in Widget.send_state(self, key)
#     584 state, buffer_paths, buffers = _remove_buffers(state)
#     585 msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 586 self._send(msg, buffers=buffers)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:825, in Widget._send(self, msg, buffers)
#     823 """Sends a message to the model in the front-end."""
#     824 if self.comm is not None and (self.comm.kernel is not None if hasattr(self.comm, "kernel") else True):
# --> 825     self.comm.send(data=msg, buffers=buffers)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/comm/base_comm.py:113, in BaseComm.send(self, data, metadata, buffers)
#     111 def send(self, data=None, metadata=None, buffers=None):
#     112     """Send a message to the frontend-side version of this comm"""
# --> 113     self.publish_msg(
#     114         "comm_msg",
#     115         data=data,
#     116         metadata=metadata,
#     117         buffers=buffers,
#     118     )
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/ipykernel/comm/comm.py:43, in BaseComm.publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      40 if self.kernel is None:
#      41     self.kernel = Kernel.instance()
# ---> 43 self.kernel.session.send(
#      44     self.kernel.iopub_socket,
#      45     msg_type,
#      46     content,
#      47     metadata=json_clean(metadata),
#      48     parent=self.kernel.get_parent(channel_from_which_to_get_parent_header),
#      49     ident=self.topic,
#      50     buffers=buffers,
#      51 )
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/jupyter_client/session.py:821, in Session.send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     819     buffers = buffers or msg.get("buffers", [])
#     820 else:
# --> 821     msg = self.msg(
#     822         msg_or_type,
#     823         content=content,
#     824         parent=parent,
#     825         header=header,
#     826         metadata=metadata,
#     827     )
#     828 if self.check_pid and os.getpid() != self.pid:
#     829     get_logger().warning("WARNING: attempted to send message from fork\n%s", msg)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/jupyter_client/session.py:662, in Session.msg(self, msg_type, content, parent, header, metadata)
#     655 """Return the nested message dict.
#     656
#     657 This format is different from what is sent over the wire. The
#     658 serialize/deserialize methods converts this nested message dict to the wire
#     659 format, which is a list of message parts.
#     660 """
#     661 msg = {}
# --> 662 header = self.msg_header(msg_type) if header is None else header
#     663 msg["header"] = header
#     664 msg["msg_id"] = header["msg_id"]
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/jupyter_client/session.py:645, in Session.msg_header(self, msg_type)
#     643 def msg_header(self, msg_type: str) -> t.Dict[str, t.Any]:
#     644     """Create a header for a message type."""
# --> 645     return msg_header(self.msg_id, msg_type, self.username, self.session)
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/jupyter_client/session.py:602, in Session.msg_id(self)
#     600 message_number = self.message_count
#     601 self.message_count += 1
# --> 602 return f"{self.session}_{os.getpid()}_{message_number}"
#
# KeyboardInterrupt:

# %%
adata_all  = sc.read_h5ad('./data/merged_3_dataset/Impaired_local_intrinsic_immunity_to_SARS_CoV_2_infection_in_severe_COVID_19.h5ad')

# %%
adata_all.shape
# Out:
# (32588, 32561)

# %% [markdown]
# Inspect the cell types observed in these studies.

# %%
counts = adata_all.obs.Coarse_Cell_Annotations.value_counts()
print(counts)
# Out:
# Coarse_Cell_Annotations
# Ciliated Cells                           10059
# Squamous Cells                            5250
# Developing Ciliated Cells                 3854
# Secretory Cells                           3633
# Goblet Cells                              2807
# Basal Cells                               1691
# T Cells                                   1475
# Erythroblasts                              986
# Macrophages                                903
# Deuterosomal Cells                         583
# Developing Secretory and Goblet Cells      406
# Ionocytes                                  399
# Mitotic Basal Cells                        266
# Dendritic Cells                            142
# B Cells                                     71
# Enteroendocrine Cells                       41
# Plasmacytoid DCs                            13
# Mast Cells                                   9
# Name: count, dtype: int64

# %% [markdown]
# To simplify visualization, let's remove the 5 minority classes.

# %%
minority_classes = counts.index[-5:].tolist()  # get the minority classes
adata_all = adata_all[~adata_all.obs.Coarse_Cell_Annotations.isin(minority_classes)]  # subset data

# reorder categories and assign back to the dataframe
adata_all.obs.Coarse_Cell_Annotations = adata_all.obs.Coarse_Cell_Annotations.cat.reorder_categories(counts.index[:-5].tolist())
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/pandas/core/generic.py:6018: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   self[name] = value

# %% [markdown]
# ### **Seeing the batch effect**

# %%
sc.pp.pca(adata_all)
sc.pp.neighbors(adata_all)
sc.tl.umap(adata_all)

# %% [markdown]
# We observe a batch effect.

# %%
for col in adata_all.obs.columns:
    print(f"{col}: {adata_all.obs[col].unique()}")
# Out:
# donor_id: ['Control_Participant7', 'COVID19_Participant13', 'COVID19_Participant31', 'Control_Participant12', 'Control_Participant21', ..., 'COVID19_Participant18', 'COVID19_Participant27', 'COVID19_Participant21', 'COVID19_Participant20', 'COVID19_Participant30']
# Length: 58
# Categories (58, object): ['COVID19_Participant2', 'COVID19_Participant3', 'COVID19_Participant4', 'COVID19_Participant5', ..., 'Control_Participant18', 'Control_Participant19', 'Control_Participant20', 'Control_Participant21']
# Peak_Respiratory_Support_WHO_Score: [0, 8, 6, 5, 4, 3, 1, 7]
# Categories (8, int64): [0, 1, 3, 4, 5, 6, 7, 8]
# Bloody_Swab: ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']
# Percent_Mitochondrial: [11.004785   34.210526    7.068224   ...  9.269663   25.603865
#   0.61349696]
# SARSCoV2_PCR_Status: ['neg', 'pos']
# Categories (2, object): ['neg', 'pos']
# SARSCoV2_PCR_Status_and_WHO_Score: ['neg_0', 'pos_8', 'pos_6', 'neg_8', 'pos_5', 'pos_4', 'pos_3', 'pos_1', 'pos_7']
# Categories (9, object): ['neg_0', 'neg_8', 'pos_1', 'pos_3', ..., 'pos_5', 'pos_6', 'pos_7', 'pos_8']
# Cohort_Disease_WHO_Score: ['Control_WHO_0', 'COVID19_WHO_6-8', 'Control_WHO_8', 'COVID19_WHO_1-5', 'ConvalescentCOVID19_WHO_0']
# Categories (5, object): ['COVID19_WHO_1-5', 'COVID19_WHO_6-8', 'Control_WHO_0', 'Control_WHO_8', 'ConvalescentCOVID19_WHO_0']
# biosample_id: ['WHO_0_Control_Participant7', 'WHO_8_COVID19_Participant13', 'WHO_6_COVID19_Participant31', 'WHO_0_Control_Participant12', 'WHO_8_Control_Participant21', ..., 'WHO_8_COVID19_Participant18', 'WHO_8_COVID19_Participant27', 'WHO_8_COVID19_Participant21', 'WHO_7_COVID19_Participant20', 'WHO_8_COVID19_Participant30']
# Length: 58
# Categories (58, object): ['WHO_0_COVID19_Participant33', 'WHO_0_COVID19_Participant34', 'WHO_0_Control_Participant1', 'WHO_0_Control_Participant2', ..., 'WHO_8_Control_Participant18', 'WHO_8_Control_Participant19', 'WHO_8_Control_Participant20', 'WHO_8_Control_Participant21']
# SingleCell_SARSCoV2_RNA_Status: ['neg', 'amb', 'pos']
# Categories (3, object): ['amb', 'neg', 'pos']
# SARSCoV2_Unspliced_TRS_Total_Corrected: [  0.   2.   1.  10.   5.  23.   6.   4.  32.  30.   3.  27.   7.  14.
#   59.  17.  40.  37.  56.  43.  15.  12.  28.  29.  21.  19.   9.  11.
#   52.  13.   8. 119.]
# SARSCoV2_Spliced_TRS_Total_Corrected: [0. 3. 6. 4. 1. 2.]
# SARSCoV2_NegativeStrand_Total_Corrected: [  0.   1.   5.   6.   2.   3.  47.  22.  25.  29.   7.  23.   4.  15.
#    8. 134. 210.  62.  16. 153.  93.  24.  10.  42.  51.   9.  11.  46.
#   20.  69.  12. 141.  27. 183. 218.  19. 380. 201.  28. 148. 149.  44.
#   90.  61.  13.  40.  39. 266. 224.  59.  17.  34. 256.  18. 166.  33.
#   99.  70. 109.  35.  30.  60.  48. 280.  14.  31. 636.]
# SARSCoV2_PositiveStrand_Total_Corrected: [0.0000e+00 1.0000e+00 1.5000e+01 3.0000e+00 8.0000e+00 1.6000e+01
#  9.6000e+01 2.4000e+01 7.0000e+00 7.8000e+01 2.8000e+01 9.0000e+00
#  2.1150e+03 4.8000e+01 1.1000e+01 1.2400e+02 1.1310e+03 1.3000e+01
#  1.2000e+01 1.8000e+01 3.1000e+01 3.9000e+01 1.0000e+01 5.9000e+01
#  2.3800e+02 7.6000e+01 3.0000e+01 1.7400e+02 4.5000e+01 2.5000e+01
#  5.7000e+01 6.0000e+00 4.3000e+01 3.6000e+01 6.4000e+01 1.1070e+03
#  3.3400e+02 2.0000e+01 1.6680e+03 8.9000e+01 1.2600e+02 2.6000e+01
#  7.7000e+01 5.5000e+01 2.1600e+02 4.2000e+01 1.1800e+02 1.2800e+02
#  3.5000e+01 1.9000e+01 1.8800e+02 1.0800e+02 5.6000e+01 7.2000e+01
#  6.3000e+01 2.7000e+01 5.0000e+00 6.9000e+01 4.6000e+01 6.5160e+03
#  6.5000e+01 3.2000e+01 4.1000e+01 5.4000e+01 4.4000e+01 1.0837e+04
#  1.4000e+01 3.3000e+01 1.1700e+02 2.9000e+01 7.7700e+02 4.3400e+02
#  3.7490e+03 6.2000e+01 7.0000e+01 3.0440e+03 4.0000e+01 1.1300e+02
#  5.0000e+01 2.5060e+03 2.3810e+03 1.0900e+02 1.3700e+02 2.3000e+01
#  1.0060e+03 9.5000e+01 4.6600e+02 1.7000e+01 3.8000e+01 7.3000e+01
#  1.4610e+03 2.9220e+03 1.3500e+03 2.0000e+00 2.2500e+02 3.4000e+01
#  3.9300e+02 2.2000e+01 1.2900e+02 8.2100e+02 1.0500e+02 1.8200e+02
#  3.2030e+03 7.2800e+02 1.6700e+02 6.4400e+02 9.2430e+03 2.8450e+03
#  7.4590e+03 5.1000e+01 1.1010e+03 4.8350e+03 5.1600e+02 1.9900e+02
#  7.3350e+03 3.0890e+03 1.6300e+02 1.2470e+03 2.3100e+02 5.7660e+03
#  9.8000e+01 5.6800e+02 1.7310e+03 1.1600e+02 1.0400e+02 2.2370e+03
#  3.8680e+03 8.1000e+01 4.3240e+03 1.2590e+03 2.1000e+01 5.8000e+01
#  1.5600e+02 2.7300e+03 7.4000e+01 4.5600e+02 1.0600e+02 2.1670e+03
#  2.3190e+03 9.2000e+01 4.7650e+03 1.1500e+02 2.6710e+03 4.1700e+02
#  3.9000e+02 1.3100e+02 3.1600e+02 1.3500e+02 7.2400e+02 1.0200e+02
#  8.0500e+02 6.5000e+02 4.0500e+02 4.0000e+00 1.9740e+03 8.9500e+02
#  7.8000e+03 9.9100e+02 3.5400e+02 2.4870e+03 1.3400e+02 4.1100e+02
#  3.5300e+02 3.3500e+02 4.2400e+02 8.2000e+01 2.6000e+02 2.0000e+02
#  6.0000e+01 2.6400e+02 1.3200e+02 1.3000e+02 9.2400e+02 1.7100e+02
#  1.1856e+04]
# SARSCoV2_Total_Corrected: [0.0000e+00 2.0000e+00 2.0000e+01 9.0000e+00 1.0000e+00 1.7000e+01
#  9.7000e+01 2.6000e+01 8.0000e+00 8.1000e+01 3.0000e+01 2.1640e+03
#  4.9000e+01 1.6000e+01 1.4000e+01 1.1000e+01 1.2600e+02 1.1630e+03
#  1.3000e+01 1.8000e+01 3.1000e+01 4.4000e+01 1.9000e+01 1.0000e+01
#  6.0000e+01 2.6400e+02 8.2000e+01 1.2000e+01 3.2000e+01 1.7500e+02
#  2.5000e+01 5.8000e+01 7.0000e+00 4.3000e+01 1.5000e+01 4.0000e+01
#  2.8000e+01 6.4000e+01 1.1440e+03 3.4300e+02 1.7140e+03 6.5000e+01
#  9.0000e+01 1.3300e+02 3.7000e+01 5.5000e+01 2.3700e+02 1.1900e+02
#  1.2900e+02 3.5000e+01 1.9100e+02 1.2000e+02 5.7000e+01 7.5000e+01
#  6.3000e+01 2.7000e+01 4.6000e+01 6.0000e+00 7.4000e+01 4.7000e+01
#  6.6880e+03 3.9000e+01 4.2000e+01 6.8000e+01 3.4000e+01 4.1000e+01
#  5.4000e+01 4.5000e+01 5.0000e+01 1.1081e+04 7.8800e+02 7.8000e+01
#  4.4100e+02 3.8150e+03 7.3000e+01 3.0640e+03 3.8000e+01 2.9000e+01
#  1.1700e+02 1.2200e+02 5.2000e+01 5.1000e+01 5.0000e+00 2.6860e+03
#  2.4820e+03 1.0900e+02 1.4000e+02 2.3000e+01 1.0330e+03 9.6000e+01
#  4.7800e+02 7.6000e+01 1.4660e+03 2.9690e+03 2.1000e+01 1.4150e+03
#  3.0000e+00 2.3500e+02 4.1100e+02 6.6000e+01 8.4600e+02 1.3600e+02
#  2.0600e+02 3.2860e+03 7.4400e+02 1.6900e+02 6.5400e+02 3.6000e+01
#  9.4430e+03 2.8900e+03 7.6850e+03 5.3000e+01 1.1710e+03 5.0960e+03
#  5.3800e+02 2.0000e+02 7.7710e+03 3.3200e+03 1.6700e+02 1.2800e+03
#  2.3900e+02 5.9570e+03 1.1000e+02 6.2000e+02 3.3000e+01 1.8950e+03
#  1.6100e+02 1.0700e+02 2.3440e+03 3.9440e+03 6.9000e+01 4.3830e+03
#  1.2740e+03 5.9000e+01 1.6600e+02 2.7980e+03 4.8400e+02 1.1600e+02
#  2.2090e+03 2.4000e+01 2.6150e+03 1.0300e+02 5.0030e+03 2.7510e+03
#  4.3800e+02 4.2000e+02 1.3400e+02 3.5600e+02 1.3900e+02 7.4600e+02
#  8.4500e+02 9.2500e+02 5.8000e+02 4.0000e+00 1.2800e+02 2.0180e+03
#  9.1100e+02 7.9510e+03 1.0060e+03 3.7200e+02 2.5140e+03 1.3800e+02
#  4.1500e+02 4.3500e+02 1.7900e+02 1.3500e+02 1.3200e+02 9.2000e+01
#  4.5700e+02 4.6500e+02 4.1000e+02 1.1500e+02 3.2800e+02 2.5500e+02
#  8.5000e+01 1.1300e+02 1.2700e+02 2.9000e+02 1.6500e+02 1.2160e+03
#  7.2000e+01 1.7700e+02 1.2612e+04]
# Coarse_Cell_Annotations: ['Developing Ciliated Cells', 'Ciliated Cells', 'Secretory Cells', 'Squamous Cells', 'Goblet Cells', ..., 'Mitotic Basal Cells', 'Macrophages', 'Ionocytes', 'Developing Secretory and Goblet Cells', 'Erythroblasts']
# Length: 13
# Categories (13, object): ['Ciliated Cells', 'Squamous Cells', 'Developing Ciliated Cells', 'Secretory Cells', ..., 'Deuterosomal Cells', 'Developing Secretory and Goblet Cells', 'Ionocytes', 'Mitotic Basal Cells']
# Detailed_Cell_Annotations: ['Developing Ciliated Cells', 'FOXJ1 high Ciliated Cells', 'BEST4 high Cilia high Ciliated Cells', 'Cilia high Ciliated Cells', 'SERPINB11 high Secretory Cells', ..., 'FFAR4 high Macrophages', 'HOPX high Squamous Cells', 'Interferon Responsive Cytotoxic CD8 T Cells', 'Erythroblasts', 'Interferon Responsive Secretory Cells']
# Length: 34
# Categories (34, object): ['AZGP1 SCGB3A1 LTF high Goblet Cells', 'AZGP1 high Goblet Cells', 'BEST4 high Cilia high Ciliated Cells', 'BPIFA1 and Chemokine high Secretory Cells', ..., 'SCGB1A1 high Goblet Cells', 'SERPINB11 high Secretory Cells', 'SPRR2D high Squamous Cells', 'VEGFA high Squamous Cells']
# Annotation: ['Developing Ciliated Cells', 'Ciliated Cells', 'Secretory Cells', 'Squamous Cells', 'Goblet Cells', ..., 'Mitotic Basal Cells', 'Macrophages', 'Ionocytes', 'Developing Secretory and Goblet Cells', 'Erythroblasts']
# Length: 13
# Categories (13, object): ['Basal Cells', 'Ciliated Cells', 'Deuterosomal Cells', 'Developing Ciliated Cells', ..., 'Mitotic Basal Cells', 'Secretory Cells', 'Squamous Cells', 'T Cells']
# assay_ontology_term_id: ['EFO:0030019']
# Categories (1, object): ['EFO:0030019']
# cell_type_ontology_term_id: ['CL:0000064', 'CL:0000151', 'CL:0000076', 'CL:0002480', 'CL:0000625', ..., 'CL:0000863', 'CL:0000084', 'CL:0005006', 'CL:0000794', 'CL:0000765']
# Length: 13
# Categories (13, object): ['CL:0000064', 'CL:0000076', 'CL:0000084', 'CL:0000151', ..., 'CL:0000863', 'CL:0002480', 'CL:0005006', 'CL:0005012']
# development_stage_ontology_term_id: ['HsapDv:0000240', 'HsapDv:0000238', 'HsapDv:0000241', 'HsapDv:0000242', 'HsapDv:0000239', 'HsapDv:0000237', 'HsapDv:0000243']
# Categories (7, object): ['HsapDv:0000237', 'HsapDv:0000238', 'HsapDv:0000239', 'HsapDv:0000240', 'HsapDv:0000241', 'HsapDv:0000242', 'HsapDv:0000243']
# disease_ontology_term_id: ['PATO:0000461', 'MONDO:0100096', 'MONDO:0021113', 'MONDO:0100233']
# Categories (4, object): ['MONDO:0021113', 'MONDO:0100096', 'MONDO:0100233', 'PATO:0000461']
# self_reported_ethnicity_ontology_term_id: ['unknown']
# Categories (1, object): ['unknown']
# is_primary_data: [ True]
# organism_ontology_term_id: ['NCBITaxon:9606']
# Categories (1, object): ['NCBITaxon:9606']
# sex_ontology_term_id: ['PATO:0000384', 'PATO:0000383']
# Categories (2, object): ['PATO:0000383', 'PATO:0000384']
# tissue_ontology_term_id: ['UBERON:0001728']
# Categories (1, object): ['UBERON:0001728']
# suspension_type: ['cell']
# Categories (1, object): ['cell']
# cell_type: ['ciliated cell', 'secretory cell', 'squamous epithelial cell', 'nasal mucosa goblet cell', 'CD8-positive, alpha-beta T cell', ..., 'inflammatory macrophage', 'T cell', 'ionocyte', 'CD8-positive, alpha-beta cytotoxic T cell', 'erythroblast']
# Length: 13
# Categories (13, object): ['ciliated cell', 'squamous epithelial cell', 'T cell', 'secretory cell', ..., 'inflammatory macrophage', 'nasal mucosa goblet cell', 'ionocyte', 'multi-ciliated epithelial cell']
# assay: ['Seq-Well S3']
# Categories (1, object): ['Seq-Well S3']
# disease: ['normal', 'COVID-19', 'respiratory failure', 'long COVID-19']
# Categories (4, object): ['respiratory failure', 'COVID-19', 'long COVID-19', 'normal']
# organism: ['Homo sapiens']
# Categories (1, object): ['Homo sapiens']
# sex: ['male', 'female']
# Categories (2, object): ['female', 'male']
# tissue: ['nasopharynx']
# Categories (1, object): ['nasopharynx']
# self_reported_ethnicity: ['unknown']
# Categories (1, object): ['unknown']
# development_stage: ['sixth decade human stage', 'fourth decade human stage', 'seventh decade human stage', 'eighth decade human stage', 'fifth decade human stage', 'third decade human stage', 'ninth decade human stage']
# Categories (7, object): ['third decade human stage', 'fourth decade human stage', 'fifth decade human stage', 'sixth decade human stage', 'seventh decade human stage', 'eighth decade human stage', 'ninth decade human stage']

# %% [markdown]
# ### **BBKNN**

# %% [markdown]
# It can be well-resolved using [BBKNN](https://github.com/Teichlab/bbknn) [[Polanski19]](https://doi.org/10.1093/bioinformatics/btz625).

# %%
# %%time
sc.external.pp.bbknn(adata_all, batch_key='batch')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/external/pp/_bbknn.py:134, in bbknn(adata, batch_key, use_rep, approx, use_annoy, metric, copy, neighbors_within_batch, n_pcs, trim, annoy_n_trees, pynndescent_n_neighbors, pynndescent_random_state, use_faiss, set_op_mix_ratio, local_connectivity, **kwargs)
#     132 except ImportError:
#     133     raise ImportError('Please install bbknn: `pip install bbknn`.')
# --> 134 return bbknn(
#     135     adata=adata,
#     136     batch_key=batch_key,
#     137     use_rep=use_rep,
#     138     approx=approx,
#     139     use_annoy=use_annoy,
#     140     metric=metric,
#     141     copy=copy,
#     142     neighbors_within_batch=neighbors_within_batch,
#     143     n_pcs=n_pcs,
#     144     trim=trim,
#     145     annoy_n_trees=annoy_n_trees,
#     146     pynndescent_n_neighbors=pynndescent_n_neighbors,
#     147     pynndescent_random_state=pynndescent_random_state,
#     148     use_faiss=use_faiss,
#     149     set_op_mix_ratio=set_op_mix_ratio,
#     150     local_connectivity=local_connectivity,
#     151     **kwargs,
#     152 )
#
# File ~/miniconda3/envs/ipy/lib/python3.11/site-packages/bbknn/__init__.py:100, in bbknn(adata, batch_key, use_rep, key_added, copy, **kwargs)
#      97 #basic sanity checks to begin
#      98 #is our batch key actually present in the object?
#      99 if batch_key not in adata.obs:
# --> 100 	raise ValueError("Batch key '"+batch_key+"' not present in `adata.obs`.")
#     101 #do we have a computed PCA?
#     102 if use_rep not in adata.obsm.keys():
#
# ValueError: Batch key 'batch' not present in `adata.obs`.

# %%
sc.tl.umap(adata_all)

# %%
sc.pl.umap(adata_all, color=['batch', 'celltype'])
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# If one prefers to work more iteratively starting from one reference dataset, one can use ingest.

# %% [markdown]
# ### **Mapping onto a reference batch using ingest**

# %% [markdown]
# Choose one reference batch for training the model and setting up the neighborhood graph (here, a PCA) and separate out all other batches.
#
# As before, the model trained on the reference batch will explain the biological variation observed within it.

# %%
adata_ref = adata_all[adata_all.obs.batch == '0']

# %% [markdown]
# Compute the PCA, neighbors and UMAP on the reference data.

# %%
sc.pp.pca(adata_ref)
sc.pp.neighbors(adata_ref)
sc.tl.umap(adata_ref)

# %% [markdown]
# The reference batch contains 12 of the 19 cell types across all batches.

# %%
sc.pl.umap(adata_ref, color='celltype')
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# Iteratively map labels (such as 'celltype') and embeddings (such as 'X_pca' and 'X_umap') from the reference data onto the query batches.

# %%
adatas = [adata_all[adata_all.obs.batch == i].copy() for i in ['1', '2', '3']]

# %%
sc.settings.verbosity = 2  # a bit more logging
for iadata, adata in enumerate(adatas):
    print(f'... integrating batch {iadata+1}')
    adata.obs['celltype_orig'] = adata.obs.celltype  # save the original cell type
    sc.tl.ingest(adata, adata_ref, obs='celltype')
# Out:
# ... integrating batch 1
# running ingest
#     finished (0:00:03)
# ... integrating batch 2
# running ingest
#     finished (0:00:04)
# ... integrating batch 3
# running ingest
#     finished (0:00:01)

# %% [markdown]
# Each of the query batches now carries annotation that has been contextualized with `adata_ref`. By concatenating, we can view it together.

# %%
adata_concat = adata_ref.concatenate(adatas)
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/anndata/_core/anndata.py:1755: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(

# %%
adata_concat.obs.celltype = adata_concat.obs.celltype.astype('category')
adata_concat.obs.celltype = adata_concat.obs.celltype.cat.reorder_categories(adata_ref.obs.celltype.cat.categories)  # fix category ordering
adata_concat.uns['celltype_colors'] = adata_ref.uns['celltype_colors']  # fix category coloring

# %%
sc.pl.umap(adata_concat, color=['batch', 'celltype'])
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# Compared to the BBKNN result, this is maintained clusters in a much more pronounced fashion. If one already observed a desired continuous structure (as in the hematopoietic datasets, for instance), `ingest` allows to easily maintain this structure.

# %% [markdown]
# ### **Evaluating consistency**

# %% [markdown]
# Let us subset the data to the query batches.

# %%
adata_query = adata_concat[adata_concat.obs.batch.isin(['1', '2', '3'])]

# %% [markdown]
# The following plot is a bit hard to read, hence, move on to confusion matrices below.

# %%
sc.pl.umap(
    adata_query, color=['batch', 'celltype', 'celltype_orig'], wspace=0.4)
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_utils.py:430: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# #### **Cell types conserved across batches**

# %% [markdown]
# Let us first focus on cell types that are conserved with the reference, to simplify reading of the confusion matrix.

# %%
obs_query = adata_query.obs
conserved_categories = obs_query.celltype.cat.categories.intersection(obs_query.celltype_orig.cat.categories)  # intersected categories
obs_query_conserved = obs_query.loc[obs_query.celltype.isin(conserved_categories) & obs_query.celltype_orig.isin(conserved_categories)]  # intersect categories

obs_query_conserved['celltype'] = obs_query_conserved.celltype.cat.remove_unused_categories()  # remove unused categories
obs_query_conserved['celltype_orig'] = obs_query_conserved.celltype_orig.cat.remove_unused_categories()  # remove unused categories

# For the reorder_categories method:
obs_query_conserved['celltype_orig'] = obs_query_conserved.celltype_orig.cat.reorder_categories(obs_query_conserved.celltype.cat.categories)  # fix category ordering
# Out:
# /tmp/ipykernel_19141/3962354674.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_query_conserved['celltype'] = obs_query_conserved.celltype.cat.remove_unused_categories()  # remove unused categories
# /tmp/ipykernel_19141/3962354674.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_query_conserved['celltype_orig'] = obs_query_conserved.celltype_orig.cat.remove_unused_categories()  # remove unused categories
# /tmp/ipykernel_19141/3962354674.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obs_query_conserved['celltype_orig'] = obs_query_conserved.celltype_orig.cat.reorder_categories(obs_query_conserved.celltype.cat.categories)  # fix category ordering

# %%
pd.crosstab(obs_query_conserved.celltype, obs_query_conserved.celltype_orig)
# Out:
# celltype_orig  alpha  beta  ductal  acinar  delta  gamma  endothelial
# celltype
# alpha           1814     3      16       0      1     20            0
# beta              54   806       4       1     10     37            0
# ductal             6     6     684     242      0      0            0
# acinar             2     3       3     165      0      3            0
# delta              6     3       1       0    305     72            0
# gamma              1     5       0       1      0    184            0
# endothelial        2     0       0       0      0      0           36

# %% [markdown]
# Overall, the conserved cell types are also mapped as expected. The main exception are some acinar cells in the original annotation that appear as acinar cells. However, already the reference data is observed to feature a cluster of both acinar and ductal cells, which explains the discrepancy, and indicates a potential inconsistency in the initial annotation.

# %% [markdown]
# #### **All cell types**

# %% [markdown]
# Let us now move on to look at all cell types.

# %%
pd.crosstab(adata_query.obs.celltype, adata_query.obs.celltype_orig)
# Out:
# celltype_orig       PSC  acinar  alpha  beta  co-expression  delta  dropped  ductal  endothelial  epsilon  gamma  mast  mesenchymal  mesenchyme  not applicable  unclassified endocrine
# celltype
# alpha                 0       0   1814     3              3      1       39      16            0        3     20     7            0           0             311                       9
# beta                  1       1     54   806             36     10       42       4            0        0     37     0            0           1             522                      24
# ductal                0     242      6     6              0      0       38     684            0        0      0     0            2           0              95                       1
# acinar                0     165      2     3              0      0       23       3            0        0      3     0            0           0              90                       0
# delta                 0       0      6     3              0    305       13       1            0        6     72     0            0           0              95                       7
# gamma                 0       1      1     5              0      0        1       0            0        1    184     0            0           0              15                       0
# endothelial           1       0      2     0              0      0        6       0           36        0      0     0            0           6               7                       0
# activated_stellate   48       1      1     1              0      0       11       6            0        0      0     0           78          20              17                       0
# quiescent_stellate    4       0      1     1              0      0        5       1            1        0      0     0            0           0               1                       0
# macrophage            0       0      1     1              0      0        0      12            0        0      0     0            0           0               1                       0

# %% [markdown]
# We observe that PSC ([pancreatic stellate cells](https://en.wikipedia.org/wiki/Pancreatic_stellate_cell)) cells are in fact just inconsistently annotated and correctly mapped on 'activated_stellate' cells.
#
# Also, it's nice to see that 'mesenchyme' and 'mesenchymal' cells both map onto the same category. However, that category is again 'activated_stellate' and likely incorrect.

# %% [markdown]
# ### **Visualizing distributions across batches**

# %% [markdown]
# Often, batches correspond to experiments that one wants to compare. Scanpy offers to convenient visualization possibilities for this.
#
# 1. a density plot
# 2. a partial visualization of a subset of categories/groups in an emnbedding

# %% [markdown]
# #### **Density plot**

# %%
sc.tl.embedding_density(adata_concat, groupby='batch')
# Out:
# computing density on 'umap'

# %%
sc.pl.embedding_density(adata_concat, groupby='batch')

# %% [markdown]
# #### **Partial visualizaton of a subset of groups in embedding**

# %%
for batch in ['1', '2', '3']:
    sc.pl.umap(adata_concat, color='batch', groups=[batch])
# Out:
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/asus/miniconda3/envs/ipy/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
